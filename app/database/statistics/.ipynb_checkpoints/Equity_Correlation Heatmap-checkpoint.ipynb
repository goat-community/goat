# %%
#Import modules

import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sp
from scipy.stats import linregress
from scipy.stats import pearsonr
import seaborn as sns

print("Import successfull")
# Out:
# Import successfull

# %%
#Connection to database
conn = psycopg2.connect(database="goat", user="goat", password="earlmanigault", host="localhost", port="65432")
cur = conn.cursor()
print("Opened database successfully")
# Out:
# Opened database successfully

# %%
#Load data and pre processing
data = pd.read_sql_query("SELECT a.*, p.* from grid_access_20 a, grid_population p where a.grid_id = p.grid_id;", conn, index_col=None, coerce_float=True, params=None, parse_dates=None, chunksize=None)
print("Tables selected successfully")
# Out:
# Tables selected successfully

# %%
amenities_food = ['grocery_shops','supermarket','discount_supermarket','organic']
amenities_education = ['nursery','kindergarten','after_school','grundschule','hauptschule_mittelschule','realschule','gymnasium']
amenities_health = ['pharmacy','dentist','general_practitioner','paediatrician','gynaecologist']
amenities_transport = ['bus_stop','tram_stop','subway_entrance','rail_station']
origin = ['nomigr','migr','foreigner']
hh = ['hh_nochild','hh_child','hh_sp','hh_tp']

# %%
# health, origin
df = data.corr()
ax = sns.heatmap(
    df[amenities_health][25:28], 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
)
# Out:
# [Text(0, 0.5, 'nomigr'), Text(0, 1.5, 'migr'), Text(0, 2.5, 'foreigner')]

# %%
#education, origin
df = data.corr()
ax = sns.heatmap(
    df[amenities_education][25:28], 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
)
# Out:
# [Text(0, 0.5, 'nomigr'), Text(0, 1.5, 'migr'), Text(0, 2.5, 'foreigner')]

# %%
#food, origin
df = data.corr()
df[amenities_food][25:28]
ax = sns.heatmap(
    df[amenities_food][25:28], 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
)
# Out:
# [Text(0, 0.5, 'nomigr'), Text(0, 1.5, 'migr'), Text(0, 2.5, 'foreigner')]

# %%
#transport, origin
df = data.corr()
df[amenities_transport][25:28]
ax = sns.heatmap(
    df[amenities_transport][25:28], 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
)
# Out:
# [Text(0, 0.5, 'nomigr'), Text(0, 1.5, 'migr'), Text(0, 2.5, 'foreigner')]

# %%
# education, households
df = data.corr()
ax = sns.heatmap(
    df[amenities_education][34:38], 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
)
# Out:
# [Text(0, 0.5, 'hh_nochild'),
#  Text(0, 1.5, 'hh_child'),
#  Text(0, 2.5, 'hh_sp'),
#  Text(0, 3.5, 'hh_tp')]

# %%
# health, households
df = data.corr()
ax = sns.heatmap(
    df[amenities_health][34:38], 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
)
# Out:
# [Text(0, 0.5, 'hh_nochild'),
#  Text(0, 1.5, 'hh_child'),
#  Text(0, 2.5, 'hh_sp'),
#  Text(0, 3.5, 'hh_tp')]

# %%
# food, households
df = data.corr()
ax = sns.heatmap(
    df[amenities_food][34:38], 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
)
# Out:
# [Text(0, 0.5, 'hh_nochild'),
#  Text(0, 1.5, 'hh_child'),
#  Text(0, 2.5, 'hh_sp'),
#  Text(0, 3.5, 'hh_tp')]

# %%
# transport, households
df = data.corr()
ax = sns.heatmap(
    df[amenities_transport][34:38], 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
)
# Out:
# [Text(0, 0.5, 'hh_nochild'),
#  Text(0, 1.5, 'hh_child'),
#  Text(0, 2.5, 'hh_sp'),
#  Text(0, 3.5, 'hh_tp')]
