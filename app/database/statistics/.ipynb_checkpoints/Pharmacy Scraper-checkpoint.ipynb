# %%
from bs4 import BeautifulSoup
import pandas 
from selenium import webdriver
import openpyxl
import csv
import os
import re

print('import of modules successful')
os.chdir(r'C:\Users\sebas\Documents\Privat\Uni\Umweltingenieurwesen\Masterarbeit')
# Out:
# import of modules successful

# %%
driver = webdriver.Firefox(executable_path=r'C:\Users\sebas\Documents\Privat\Uni\Umweltingenieurwesen\Masterarbeit\WebScraping\geckodriver.exe')
driver
# Out:
# <selenium.webdriver.firefox.webdriver.WebDriver (session="0e2c1272-fe1b-4be5-88f6-03dd2b15075c")>

# %%
lat = [48.13,48.75]
long = [11.45,11.3]
driver.get(r'https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&zeigeKarte=true')
#https://dienste.kvb.de/arztsuche/app/erweiterteSucheAusfuehrung.htm\fachgebiete=&name=&adresse=&arztArt=hausarzt&geschlecht=&sprechzeitenTag=&barrierefreiheit=&zustatzBezeichnungen=&zusatzWeiterbildungen=&genehmigungen=&fremdsprachen=&bezirksstellen=8&bsnrLanrHnr=&geocodeResult=&geoTest=
results = []
content = driver.page_source
soup = BeautifulSoup(content)
#for element in soup.findAll(attrs={'a class': 'name'}):
#    name = element.find('a')
#    results.append(name.text)
    
#results
#print(soup.prettify())
soup.find_all()
# Out:
# [<html lang="de" xml:lang="de" xmlns="http://www.w3.org/1999/xhtml"><head>
#  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#  <title>
#          KVB Arztsuche: Hausarzt, Landkreis [München, Landeshauptstadt]
#      </title>
#  <link href="/arztsuche/common/css/my_layout.css" media="screen" rel="stylesheet" type="text/css"/>
#  <link href="/arztsuche/common/css/screen/common_gui.css" media="screen" rel="stylesheet" type="text/css"/>
#  <link href="/arztsuche/common/css/screen/cg_topnav.css" media="screen" rel="stylesheet" type="text/css"/>
#  <link href="/arztsuche/common/css/print/common_gui.css" media="print, embossed" rel="stylesheet" type="text/css"/>
#  <link href="/arztsuche/project/css/project.css" media="screen" rel="stylesheet" type="text/css"/>
#  <link href="/arztsuche/project/css/project_print.css" media="print" rel="stylesheet" type="text/css"/>
#  <link href="/arztsuche/project/css/autocomplete/jquery.autocomplete.css" media="screen" rel="stylesheet" type="text/css"/>
#  <link href="/arztsuche/project/css/autocomplete/thickbox.css" media="screen" rel="stylesheet" type="text/css"/>
#  <link href="/arztsuche/project/img/icons/favicon.ico" rel="icon" type="image/x-icon"/>
#  <link href="/arztsuche/project/img/icons/favicon.ico" media="screen" rel="stylesheet" type="text/css"/>
#  <script async="" defer="" src="https://dienste.kvb.de/traffic/piwik.js" type="text/javascript"></script><script src="/arztsuche/project/js/utils.js" type="text/javascript">
#  </script>
#  <script src="/arztsuche/project/js/jquery.min.js" type="text/javascript">
#  </script>
#  <!--  JQuery-UI Dateien anbinden -->
#  <link href="/arztsuche/project/css/jquery-ui.css" media="screen" rel="stylesheet" type="text/css"/>
#  <script src="/arztsuche/project/js/jquery-ui.min.js" type="text/javascript"></script>
#  <script src="/arztsuche/project/js/jquery.cookie.min.js" type="text/javascript"></script>
#  <!-- Lade Skripte für Autocomplete -->
#  <script src="/arztsuche/project/js/jquery.autocomplete.js" type="text/javascript">
#  </script>
#  <script src="/arztsuche/project/js/ajaxAutoCompletion.js" type="text/javascript">
#  </script>
#  <script src="/arztsuche/project/js/jquery.ajaxQueue.js" type="text/javascript">
#  </script>
#  <script src="/arztsuche/project/js/chili-1.7.pack.js" type="text/javascript">
#  </script>
#  <script src="/arztsuche/project/js/cargojsutils.js" type="text/javascript">
#  </script>
#  <!-- Lade Skripte für Geocoding und Maps API-->
#  <script src="/arztsuche/project/js/json.js" type="text/javascript"></script>
#  <script src="/arztsuche/project/js/geocoder.js?version=1" type="text/javascript">
#  </script>
#  <!-- Lade Skripte für Matomo -->
#  <script src="/arztsuche/project/js/matomo.js" type="text/javascript">
#  </script>
#  </head>
#  <body>
#  <div id="page_margins">
#  <div id="page">
#  <div id="header">
#  <div class="WARN">Achtung: die Arztsuche wird aktuell überarbeitet und dadurch kann es zur Einschränkung der Suchperformance bzw. der Suchergebnisse kommen. <br/>
#                  In unseren aktuellen Arztlisten, unter <a href="https://www.kvb.de/service/arztverzeichnis/">https://www.kvb.de/service/arztverzeichnis/</a> können Sie alle Haus- und Fachärzte sowie Psychotherapeuten je Bezirksstelle alphabetisch sortiert erkennen.
#              </div>
#  <a href="http://www.kvb.de/home/" title="Kassenärztliche Vereinigung Bayerns"></a>
#  <div id="logo">
#  <a class="logo" href="http://www.kvb.de/"><img alt="KVB" border="0" height="98" src="/arztsuche/project/img/general/logo_kvb.jpg" title="KVB" width="220"/></a>
#  </div>
#  </div>
#  <!-- <div id="header_temp"></div> -->
#  <div id="main">
#  <div id="arztsuche">
#  <div id="col1">
#  <div id="col1_content"></div>
#  </div>
#  <div id="col3">
#  <div class="clearfix" id="col3_content">
#  <div class="subcolumns">
#  <div class="suchergebnisse_hauptdiv" id="suchergebnisse">
#  <div class="suchergebnisse_titel">Suche nach Arzt oder Psychotherapeut</div>
#  <table class="suchergebnisse_titeltabelle">
#  <tbody><tr>
#  <td class="suchergebnisse_titeltabelle_textspalte">
#  <div class="suchergebnisse_titeltabelle_ergebnisseangaben">
#                  Ergebnisse: 1-10 von 100<br/>
#
#                      Ihre Suche ergab 100 oder mehr Treffer, bitte wählen Sie weitere Suchkriterien um die Ergebniszahl einzuschränken.
#
#
#                      <br/>
#  					Hinweis: Es werden alle Ärzte /Psychotherapeuten, die der Veröffentlichungspflicht unterliegen, angezeigt.
#
#              </div>
#  <div>
#  <span class="suchkriterien_bechreibung">Suche nach: </span>
#  <span class="suchkriterien_werte">Hausarzt, Landkreis [München, Landeshauptstadt]</span>
#  </div>
#  </td>
#  <td class="suchergebnisse_titeltabelle_knopfspalte" style="text-align: top">
#  <div>
#  <form action="suchkriterienAendern.htm" method="get" style="margin: 0px; padding: 0px;">
#  <input class="BUTTON BACKWARD INVERS" type="submit" value="Suchkriterien ändern"/>
#  <input name="hashwert" type="hidden" value="ec612783a8c5320de977f02cedce5c"/>
#  <input name="lat" type="hidden" value="48.1351253"/>
#  <input name="lng" type="hidden" value="11.5819805"/>
#  </form>
#  <br/>
#  <form action="suchkriterienAendern.htm" method="get" style="margin: 0px; padding: 0px;">
#  <input class="BUTTON BACKWARD INVERS" type="submit" value="Neue Suche"/>
#  <input name="neu" type="hidden" value="true"/>
#  </form>
#  </div>
#  </td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <br/>
#  <div class="suchergebnisse_navigationsbalken_oben">
#  <table class="suchergebnisse_navigationsbalken">
#  <tbody><tr>
#  <td class="suchergebnisse_navigationsbalken_zelle_links" width="33%">
#
#
#
#
#
#
#              </td>
#  <td class="suchergebnisse_navigationsbalken_zelle_mitte" width="33%">
#                  Treffer 1 bis 10 von 100
#              </td>
#  <td class="suchergebnisse_navigationsbalken_zelle_rechts" width="33%">
#  <form action="suchergebnisse.htm" method="get" style="margin: 0px; padding: 0px">
#  <input class="BUTTON FORWARD" id="1" type="submit" value="nächste Seite"/>
#  <input name="hashwert" type="hidden" value="ec612783a8c5320de977f02cedce5c"/>
#  <input name="lat" type="hidden" value="48.1351253"/>
#  <input name="lng" type="hidden" value="11.5819805"/>
#  <input name="page" type="hidden" value="2"/>
#  <input name="zeigeKarte" type="hidden" value="true"/>
#  <input name="resultCount" type="hidden" value="100"/>
#  </form>
#  </td>
#  </tr>
#  </tbody></table>
#  </div>
#  <div class="suchergebnisse_liste">
#  <div class="suchergebnisse_praxis_tabelle">
#  <noscript>
#  <td id="mehrInfoZelle1" style="border-bottom: 1px solid #DBDBDB !important">
#  </td>
#  </noscript><noscript>
#  <td id="mehrInfoZelle2" style="border-bottom: 1px solid #DBDBDB !important">
#  </td>
#  </noscript><table class="suchergebnisse_praxis_innere_tabelle">
#  <tbody><tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"></td>
#  <td class="sprechzeiten_zelle leere_zeile"></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle">
#  <table class="entfernung_tabelle">
#  <tbody><tr>
#  <td class="blase">
#  <div class="blase">
#  <img src="/arztsuche/project/img/icons/google/gm_icon_arztinliste_1.png"/>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_angaben">
#                              44 m
#                      </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="name_zelle">
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=4d923269555ac94f8bf869fc64b1493a">Dr. med. Monika Grau</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Allgemeinmedizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <hr/>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Homöopathie
#                                      <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="adresse_zelle">
#  <table class="adresse_tabelle">
#  <!-- im Fall von speziellen Leistungsortarten auch den Namen der Betriebsstaette hier ausgeben -->
#  <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Tal 43
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>
#  </tbody></table>
#  <table class="tel_tabelle">
#  <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-29168160
#
#
#                          <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="sprechzeiten_zelle">
#  <div class="header">Sprechzeiten:</div>
#  <table class="sprechzeiten_tabelle">
#  <tbody><tr>
#  <td class="wochentag">
#                                  Mo:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-13:00 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Di:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-13:00 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Mi:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-13:00 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Do:
#                          </td>
#  <td class="uhrzeiten">
#                                  15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Fr:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-13:00
#                          </td>
#  </tr>
#  <tr>
#  <td colspan="2">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile" style="border-bottom: 1px solid #DBDBDB !important"></td>
#  <td class="adresse_zelle leere_zeile" style="border-bottom: 1px solid #DBDBDB !important"><span style="font-size: 10px !important;padding-right: 8px !important;">Betriebsstätte einer örtlichen Gemeinschaftspraxis</span></td>
#  <script language="javascript">
#              document.write("<td id='mehrInfoZelle1' class='mehr_info_zelle' style='border-bottom: 1px solid #DBDBDB !important'>");
#              document.write("	<div class='mehr_info_div'>");
#              document.write("		<a href='#' id='suchergebnisse_zusatzinfo_link1' class='mehr_info_link'>[+] mehr Informationen</a>");
#              document.write("	</div>");
#              document.write("</td>");
#          </script><td class="mehr_info_zelle" id="mehrInfoZelle1" style="border-bottom: 1px solid #DBDBDB !important"> <div class="mehr_info_div"> <a class="mehr_info_link" href="#" id="suchergebnisse_zusatzinfo_link1">[+] mehr Informationen</a> </div></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle_mehr_info_bereich" colspan="4">
#  <div class="suchergebnisse_zusatzinfo" id="suchergebnisse_zusatzinfo1" style="display: none;">
#  <table class="suchergebnisse_zusatzinfo">
#  <tbody><tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte">
#  <table class="bsnr_lanr">
#  <tbody><tr>
#  <td>
#  </td>
#  <td>
#  <br/>
#  <span class="zusatzinfo_text">
#  </span>
#  </td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte">
#  <span class="zusatzinfo_titel">Genehmigungen:</span>
#  <br/>
#  <span class="zusatzinfo_text">Homöopathievertrag zwischen KVB und Securvita</span>
#  <br/>
#  <span class="zusatzinfo_text">Jakobsonsche Relaxationstherapie</span>
#  <br/>
#  <span class="zusatzinfo_text">Psychosomatische Grundversorgung</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Abdomen und Retroperitoneum</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Uro-Genitalorgane</span>
#  <br/>
#  <span class="zusatzinfo_text">Videosprechstunde</span>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte">
#  <table class="gemeinschaftspraxis">
#  <tbody><tr>
#  <td class="titel_zelle">
#  												Ärzte der Praxis:
#  											</td>
#  </tr>
#  <tr>
#  <td class="arzt_zelle">
#  <span class="arzt_name">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=98f94c9f5bf45c74103ea1e1be18b1b9">Dr. med. Martina Kessel</a>
#  </span>
#  <br/>
#  <span class="arzt_fachrichtungen">
#
#  																	Fachärztin für Allgemeinmedizin
#  																<br/>
#  </span>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  </tbody></table>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"></td>
#  <td class="sprechzeiten_zelle leere_zeile"></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle">
#  </td>
#  <td class="name_zelle">
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=98f94c9f5bf45c74103ea1e1be18b1b9">Dr. med. Martina Kessel</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Allgemeinmedizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <hr/>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Akupunktur
#                                      <br/>
#
#                                      Betriebsmedizin
#                                      <br/>
#
#                                      Homöopathie
#                                      <br/>
#
#                                      Naturheilverfahren
#                                      <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="adresse_zelle">
#  <table class="adresse_tabelle">
#  <!-- im Fall von speziellen Leistungsortarten auch den Namen der Betriebsstaette hier ausgeben -->
#  <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Tal 43
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>
#  </tbody></table>
#  <table class="tel_tabelle">
#  <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-29168160
#
#
#                          <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="sprechzeiten_zelle">
#  <div class="header">Sprechzeiten:</div>
#  <table class="sprechzeiten_tabelle">
#  <tbody><tr>
#  <td class="wochentag">
#                                  Mo:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-13:00 15:00-17:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Di:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-13:00 15:00-17:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Mi:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-13:00 15:00-17:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Do:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-13:00 15:00-17:00
#                          </td>
#  </tr>
#  <tr>
#  <td colspan="2">
#                                  nach Vereinbarung
#                          </td>
#  </tr>
#  <tr>
#  <td colspan="2"> </td>
#  </tr>
#  <tr>
#  <td colspan="2"><div class="header" margin-top="20px">Telefonische Erreichbarkeit:</div></td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                              Mo:
#                      </td>
#  <td class="uhrzeiten">
#                              08:30-13:00 15:00-17:00
#                      </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                              Di:
#                      </td>
#  <td class="uhrzeiten">
#                              08:30-13:00 15:00-17:00
#                      </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                              Mi:
#                      </td>
#  <td class="uhrzeiten">
#                              08:30-13:00 15:00-17:00
#                      </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                              Do:
#                      </td>
#  <td class="uhrzeiten">
#                              08:30-13:00 15:00-17:00
#                      </td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"><span style="font-size: 10px !important;padding-right: 8px !important;">Betriebsstätte einer örtlichen Gemeinschaftspraxis</span></td>
#  <script language="javascript">
#              document.write("<td id='mehrInfoZelle2' class='mehr_info_zelle' style='border-bottom: 1px solid #DBDBDB !important'>");
#              document.write("	<div class='mehr_info_div'>");
#              document.write("		<a href='#' id='suchergebnisse_zusatzinfo_link2' class='mehr_info_link'>[+] mehr Informationen</a>");
#              document.write("	</div>");
#              document.write("</td>");
#          </script><td class="mehr_info_zelle" id="mehrInfoZelle2" style="border-bottom: 1px solid #DBDBDB !important"> <div class="mehr_info_div"> <a class="mehr_info_link" href="#" id="suchergebnisse_zusatzinfo_link2">[+] mehr Informationen</a> </div></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle_mehr_info_bereich" colspan="4">
#  <div class="suchergebnisse_zusatzinfo" id="suchergebnisse_zusatzinfo2" style="display: none;">
#  <table class="suchergebnisse_zusatzinfo">
#  <tbody><tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte">
#  <table class="bsnr_lanr">
#  <tbody><tr>
#  <td>
#  </td>
#  <td>
#  <br/>
#  <span class="zusatzinfo_text">
#  </span>
#  </td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte">
#  <span class="zusatzinfo_titel">Genehmigungen:</span>
#  <br/>
#  <span class="zusatzinfo_text">Akupunktur i.R.d. Schmerztherapie</span>
#  <br/>
#  <span class="zusatzinfo_text">Chirotherapie</span>
#  <br/>
#  <span class="zusatzinfo_text">Chirotherapie - Extremitäten</span>
#  <br/>
#  <span class="zusatzinfo_text">Homöopathievertrag zwischen KVB und Securvita</span>
#  <br/>
#  <span class="zusatzinfo_text">Psychosomatische Grundversorgung</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Abdomen und Retroperitoneum</span>
#  <br/>
#  <span class="zusatzinfo_text">Videosprechstunde</span>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte">
#  <table class="gemeinschaftspraxis">
#  <tbody><tr>
#  <td class="titel_zelle">
#  												Ärzte der Praxis:
#  											</td>
#  </tr>
#  <tr>
#  <td class="arzt_zelle">
#  <span class="arzt_name">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=4d923269555ac94f8bf869fc64b1493a">Dr. med. Monika Grau</a>
#  </span>
#  <br/>
#  <span class="arzt_fachrichtungen">
#
#  																	Fachärztin für Allgemeinmedizin
#  																<br/>
#  </span>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  </tbody></table>
#  </div>
#  </td>
#  </tr>
#  </tbody></table>
#  </div>
#  <div class="suchergebnisse_praxis_tabelle" id="naechste_tabelle">
#  <noscript>
#  <td id="mehrInfoZelle3" style="border-bottom: 1px solid #DBDBDB !important">
#  </td>
#  </noscript><table class="suchergebnisse_praxis_innere_tabelle">
#  <tbody><tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"></td>
#  <td class="sprechzeiten_zelle leere_zeile"></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle">
#  <table class="entfernung_tabelle">
#  <tbody><tr>
#  <td class="blase">
#  <div class="blase">
#  <img src="/arztsuche/project/img/icons/google/gm_icon_arztinliste_2.png"/>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_angaben">
#                              60 m
#                      </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="name_zelle">
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=aa6f5a06f26759ed8f9929e5abf352eb">Dr. med. Ruxandra Iliescu-Steiner</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Allgemeinmedizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <hr/>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Umweltmedizin
#                                      <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="adresse_zelle">
#  <table class="adresse_tabelle">
#  <!-- im Fall von speziellen Leistungsortarten auch den Namen der Betriebsstaette hier ausgeben -->
#  <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Tal 48
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>
#  </tbody></table>
#  <table class="tel_tabelle">
#  <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-294391
#
#
#                          <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="sprechzeiten_zelle">
#  <div class="header">Sprechzeiten:</div>
#  <table class="sprechzeiten_tabelle">
#  <tbody><tr>
#  <td class="wochentag">
#                                  Mo:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:00-12:00 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Di:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:00-12:00 16:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Mi:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:00-12:00 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Do:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:00-12:00 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Fr:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:00-12:00
#                          </td>
#  </tr>
#  <tr>
#  <td colspan="2">
#                                  und nach Vereinbarung
#                          </td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"><span style="font-size: 10px !important;padding-right: 8px !important;">Betriebsstätte einer Einzelpraxis</span></td>
#  <script language="javascript">
#              document.write("<td id='mehrInfoZelle3' class='mehr_info_zelle' style='border-bottom: 1px solid #DBDBDB !important'>");
#              document.write("	<div class='mehr_info_div'>");
#              document.write("		<a href='#' id='suchergebnisse_zusatzinfo_link3' class='mehr_info_link'>[+] mehr Informationen</a>");
#              document.write("	</div>");
#              document.write("</td>");
#          </script><td class="mehr_info_zelle" id="mehrInfoZelle3" style="border-bottom: 1px solid #DBDBDB !important"> <div class="mehr_info_div"> <a class="mehr_info_link" href="#" id="suchergebnisse_zusatzinfo_link3">[+] mehr Informationen</a> </div></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle_mehr_info_bereich" colspan="4">
#  <div class="suchergebnisse_zusatzinfo" id="suchergebnisse_zusatzinfo3" style="display: none;">
#  <table class="suchergebnisse_zusatzinfo">
#  <tbody><tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte">
#  <table class="bsnr_lanr">
#  <tbody><tr>
#  <td>
#  </td>
#  <td>
#  <br/>
#  <span class="zusatzinfo_text">
#  </span>
#  </td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte">
#  <span class="zusatzinfo_titel">Genehmigungen:</span>
#  <br/>
#  <span class="zusatzinfo_text">Hautkrebs-Screening - Früherkennungsuntersuchung</span>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte">
#  <span class="zusatzinfo_titel">Fremdsprachen:</span>
#  <br/>
#  <span class="zusatzinfo_text">
#
#  												Englisch
#  												<br/>
#
#  												Französisch
#  												<br/>
#
#  												Italienisch
#  												<br/>
#
#  												Rumänisch
#  												<br/>
#
#  												Spanisch
#  												<br/>
#  </span>
#  <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  </tbody></table>
#  </div>
#  </td>
#  </tr>
#  </tbody></table>
#  </div>
#  <div class="suchergebnisse_praxis_tabelle" id="naechste_tabelle">
#  <noscript>
#  <td id="mehrInfoZelle4" style="border-bottom: 1px solid #DBDBDB !important">
#  </td>
#  </noscript><table class="suchergebnisse_praxis_innere_tabelle">
#  <tbody><tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"></td>
#  <td class="sprechzeiten_zelle leere_zeile"></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle">
#  <table class="entfernung_tabelle">
#  <tbody><tr>
#  <td class="blase">
#  <div class="blase">
#  <img src="/arztsuche/project/img/icons/google/gm_icon_arztinliste_3.png"/>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_angaben">
#                              108 m
#                      </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="name_zelle">
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=b4f10a8c7eea480d3b3782df41cdc8f8">Dr. med. Michael Bäumler</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Facharzt für Innere Medizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <hr/>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Homöopathie
#                                      <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="adresse_zelle">
#  <table class="adresse_tabelle">
#  <!-- im Fall von speziellen Leistungsortarten auch den Namen der Betriebsstaette hier ausgeben -->
#  <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Tal 38
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>
#  </tbody></table>
#  <table class="tel_tabelle">
#  <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-226181
#
#
#                          <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="sprechzeiten_zelle">
#  <div class="header">Sprechzeiten:</div>
#  <table class="sprechzeiten_tabelle">
#  <tbody><tr>
#  <td class="wochentag">
#                                  Mo:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-12:30
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Di:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-12:30 14:30-17:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Mi:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-12:30
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Do:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-12:30 14:30-17:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Fr:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-12:30
#                          </td>
#  </tr>
#  <tr>
#  <td colspan="2">
#                                  und nach Vereinbarung
#                          </td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"><span style="font-size: 10px !important;padding-right: 8px !important;">Betriebsstätte einer Einzelpraxis</span></td>
#  <script language="javascript">
#              document.write("<td id='mehrInfoZelle4' class='mehr_info_zelle' style='border-bottom: 1px solid #DBDBDB !important'>");
#              document.write("	<div class='mehr_info_div'>");
#              document.write("		<a href='#' id='suchergebnisse_zusatzinfo_link4' class='mehr_info_link'>[+] mehr Informationen</a>");
#              document.write("	</div>");
#              document.write("</td>");
#          </script><td class="mehr_info_zelle" id="mehrInfoZelle4" style="border-bottom: 1px solid #DBDBDB !important"> <div class="mehr_info_div"> <a class="mehr_info_link" href="#" id="suchergebnisse_zusatzinfo_link4">[+] mehr Informationen</a> </div></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle_mehr_info_bereich" colspan="4">
#  <div class="suchergebnisse_zusatzinfo" id="suchergebnisse_zusatzinfo4" style="display: none;">
#  <table class="suchergebnisse_zusatzinfo">
#  <tbody><tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte">
#  <table class="bsnr_lanr">
#  <tbody><tr>
#  <td>
#  </td>
#  <td>
#  <br/>
#  <span class="zusatzinfo_text">
#  </span>
#  </td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte">
#  <span class="zusatzinfo_titel">Genehmigungen:</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP Asthma/COPD - Koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP KHK - Koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP Typ2 - koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">Diabetologisch qualifizierter Hausarzt LKK</span>
#  <br/>
#  <span class="zusatzinfo_text">Schulung mit Insulin</span>
#  <br/>
#  <span class="zusatzinfo_text">Schulung ohne Insulin</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Abdomen und Retroperitoneum</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Gesichts- und Halsweichteile</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Uro-Genitalorgane</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie der Schilddrüse</span>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte">
#  </td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  </tbody></table>
#  </div>
#  </td>
#  </tr>
#  </tbody></table>
#  </div>
#  <div class="suchergebnisse_praxis_tabelle" id="naechste_tabelle">
#  <table class="suchergebnisse_praxis_innere_tabelle">
#  <tbody><tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"></td>
#  <td class="sprechzeiten_zelle leere_zeile"></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle">
#  <table class="entfernung_tabelle">
#  <tbody><tr>
#  <td class="blase">
#  <div class="blase">
#  <img src="/arztsuche/project/img/icons/google/gm_icon_arztinliste_4.png"/>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_angaben">
#                              159 m
#                      </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="name_zelle">
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=cb3a38ee0423f8f487c092b4f5a8b6e4">Vasilios Itsios</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Facharzt für Innere Medizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody></table>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="adresse_zelle">
#  <table class="adresse_tabelle">
#  <!-- im Fall von speziellen Leistungsortarten auch den Namen der Betriebsstaette hier ausgeben -->
#  <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Thomas-Wimmer-Ring 9
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80539 München
#                  </td>
#  </tr>
#  </tbody></table>
#  <table class="tel_tabelle">
#  <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-21665031
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Fax.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-21665032
#
#
#                          <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="sprechzeiten_zelle">
#  <div class="header">Sprechzeiten:</div>
#  <table class="sprechzeiten_tabelle">
#  <tbody><tr>
#  <td class="wochentag">
#                                  Mo:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-13:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Di:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-13:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Mi:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-13:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Do:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-13:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Fr:
#                          </td>
#  <td class="uhrzeiten">
#                                  09:00-13:00
#                          </td>
#  </tr>
#  <tr>
#  <td colspan="2">
#                                  nach Vereinbarung
#                          </td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"><span style="font-size: 10px !important;padding-right: 8px !important;">Betriebsstätte einer Einzelpraxis</span></td>
#  <td class="name_zelle leere_zeile" style="border-bottom: 1px solid #DBDBDB !important"></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle_mehr_info_bereich" colspan="4">
#  <div class="suchergebnisse_zusatzinfo" id="suchergebnisse_zusatzinfo5" style="display: none;">
#  <table class="suchergebnisse_zusatzinfo">
#  <tbody><tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte">
#  <table class="bsnr_lanr">
#  <tbody><tr>
#  <td>
#  </td>
#  <td>
#  <br/>
#  <span class="zusatzinfo_text">
#  </span>
#  </td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte">
#  <span class="zusatzinfo_titel">Genehmigungen:</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP Asthma - Schulung NASA</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP Asthma/COPD - Koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP COPD - Schulung COBRA</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP KHK - Koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP KHK - Schulung Hypertonie (ZI)</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP Typ2 - koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">Hautkrebs-Screening - Früherkennungsuntersuchung</span>
#  <br/>
#  <span class="zusatzinfo_text">Methadongenehmigung</span>
#  <br/>
#  <span class="zusatzinfo_text">Schulung Hypertonie Zi</span>
#  <br/>
#  <span class="zusatzinfo_text">Schulung ohne Insulin</span>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte">
#  </td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  </tbody></table>
#  </div>
#  </td>
#  </tr>
#  </tbody></table>
#  </div>
#  <div class="suchergebnisse_praxis_tabelle" id="naechste_tabelle">
#  <noscript>
#  <td id="mehrInfoZelle6" style="border-bottom: 1px solid #DBDBDB !important">
#  </td>
#  </noscript><noscript>
#  <td id="mehrInfoZelle7" style="border-bottom: 1px solid #DBDBDB !important">
#  </td>
#  </noscript><noscript>
#  <td id="mehrInfoZelle8" style="border-bottom: 1px solid #DBDBDB !important">
#  </td>
#  </noscript><table class="suchergebnisse_praxis_innere_tabelle">
#  <tbody><tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"></td>
#  <td class="sprechzeiten_zelle leere_zeile"></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle">
#  <table class="entfernung_tabelle">
#  <tbody><tr>
#  <td class="blase">
#  <div class="blase">
#  <img src="/arztsuche/project/img/icons/google/gm_icon_arztinliste_5.png"/>
#  </div>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_angaben">
#                              169 m
#                      </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="name_zelle">
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=98aa96a336468eda131db968a5c2dbed">Dr. med. Maria Beykirch</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Innere Medizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody></table>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="adresse_zelle">
#  <table class="adresse_tabelle">
#  <!-- im Fall von speziellen Leistungsortarten auch den Namen der Betriebsstaette hier ausgeben -->
#  <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Zweibrückenstraße 2
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>
#  </tbody></table>
#  <table class="tel_tabelle">
#  <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229009
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Fax.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229448
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                      E-Mail:
#                  </td>
#  <td>
#  <a href="mailto:info@hausarztpraxis-isartor.de">info@hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Web:
#                  </td>
#  <td>
#  <a href="http://www.hausarztpraxis-isartor.de" target="_blank">http://www.hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="sprechzeiten_zelle">
#  <div class="header">Sprechzeiten:</div>
#  <table class="sprechzeiten_tabelle">
#  <tbody><tr>
#  <td class="wochentag">
#                                  Mo:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Di:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Mi:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Do:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Fr:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30
#                          </td>
#  </tr>
#  <tr>
#  <td colspan="2">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile" style="border-bottom: 1px solid #DBDBDB !important"></td>
#  <td class="adresse_zelle leere_zeile" style="border-bottom: 1px solid #DBDBDB !important"><span style="font-size: 10px !important;padding-right: 8px !important;">Betriebsstätte einer örtlichen Gemeinschaftspraxis</span></td>
#  <script language="javascript">
#              document.write("<td id='mehrInfoZelle6' class='mehr_info_zelle' style='border-bottom: 1px solid #DBDBDB !important'>");
#              document.write("	<div class='mehr_info_div'>");
#              document.write("		<a href='#' id='suchergebnisse_zusatzinfo_link6' class='mehr_info_link'>[+] mehr Informationen</a>");
#              document.write("	</div>");
#              document.write("</td>");
#          </script><td class="mehr_info_zelle" id="mehrInfoZelle6" style="border-bottom: 1px solid #DBDBDB !important"> <div class="mehr_info_div"> <a class="mehr_info_link" href="#" id="suchergebnisse_zusatzinfo_link6">[+] mehr Informationen</a> </div></td>
#  </tr>
#  <tr>
#  <td class="entfernung_zelle_mehr_info_bereich" colspan="4">
#  <div class="suchergebnisse_zusatzinfo" id="suchergebnisse_zusatzinfo6" style="display: none;">
#  <table class="suchergebnisse_zusatzinfo">
#  <tbody><tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>
#  <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte">
#  <table class="bsnr_lanr">
#  <tbody><tr>
#  <td>
#  </td>
#  <td>
#  <br/>
#  <span class="zusatzinfo_text">
#  </span>
#  </td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <br/>
#  </td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte">
#  <span class="zusatzinfo_titel">Genehmigungen:</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP Asthma - Schulung NASA</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP Asthma/COPD - Koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP Brustkrebs - Koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP KHK - Koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">DMP Typ2 - koordinierender Arzt</span>
#  <br/>
#  <span class="zusatzinfo_text">Diabetologisch qualifizierter Hausarzt LKK</span>
#  <br/>
#  <span class="zusatzinfo_text">Langzeit-EKG - Aufzeichnung</span>
#  <br/>
#  <span class="zusatzinfo_text">Onkologisch qualif. Arzt - SP Hämatologie</span>
#  <br/>
#  <span class="zusatzinfo_text">Psychosomatische Grundversorgung</span>
#  <br/>
#  <span class="zusatzinfo_text">Schulung mit Insulin</span>
#  <br/>
#  <span class="zusatzinfo_text">Schulung ohne Insulin</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Abdomen und Retroperitoneum</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Extrakranieller Gefäße (Duplex)</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Gefäße Extremitäten (Duplex)</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Gesichts- und Halsweichteile</span>
#  <br/>
#  <span class="zusatzinfo_text">Sonographie Thoraxorgane</span>
#  <br/>
# ...
#  </span>, <a href="/arztsuche/app/arztInfo.htm?arztCode=87823ec0e2b3da9441a6bc372c191538">Dr. med. Kathrin Ronel</a>, <br/>, <span class="arzt_fachrichtungen">
#
#  																	Fachärztin für Innere Medizin
#  																<br/>
#  </span>, <br/>, <tr>
#  <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>
#  <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>
#  </tr>, <td class="suchergebnisse_zusatzinfo_erste_spalte leere_zeile_zusatzinfo"></td>, <td class="suchergebnisse_zusatzinfo_zweite_spalte leere_zeile_zusatzinfo"></td>, <td class="suchergebnisse_zusatzinfo_dritte_spalte leere_zeile_zusatzinfo"></td>, <tr>
#  <td class="entfernung_zelle leere_zeile_right_border"></td>
#  <td class="name_zelle leere_zeile"></td>
#  <td class="adresse_zelle leere_zeile"></td>
#  <td class="sprechzeiten_zelle leere_zeile"></td>
#  </tr>, <td class="entfernung_zelle leere_zeile_right_border"></td>, <td class="name_zelle leere_zeile"></td>, <td class="adresse_zelle leere_zeile"></td>, <td class="sprechzeiten_zelle leere_zeile"></td>, <tr>
#  <td class="entfernung_zelle">
#  </td>
#  <td class="name_zelle">
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=87823ec0e2b3da9441a6bc372c191538">Dr. med. Kathrin Ronel</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Innere Medizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <hr/>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Palliativmedizin
#                                      <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="adresse_zelle">
#  <table class="adresse_tabelle">
#  <!-- im Fall von speziellen Leistungsortarten auch den Namen der Betriebsstaette hier ausgeben -->
#  <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Zweibrückenstraße 2
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>
#  </tbody></table>
#  <table class="tel_tabelle">
#  <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229009
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Fax.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229448
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                      E-Mail:
#                  </td>
#  <td>
#  <a href="mailto:info@hausarztpraxis-isartor.de">info@hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Web:
#                  </td>
#  <td>
#  <a href="http://www.hausarztpraxis-isartor.de" target="_blank">http://www.hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td class="sprechzeiten_zelle">
#  <div class="header">Sprechzeiten:</div>
#  <table class="sprechzeiten_tabelle">
#  <tbody><tr>
#  <td class="wochentag">
#                                  Mo:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Di:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Mi:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Do:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30 15:00-18:00
#                          </td>
#  </tr>
#  <tr>
#  <td class="wochentag">
#                                  Fr:
#                          </td>
#  <td class="uhrzeiten">
#                                  08:30-12:30
#                          </td>
#  </tr>
#  <tr>
#  <td colspan="2">
#                                  und nach Vereinbarung
#                          </td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>, <td class="entfernung_zelle">
#  </td>, <td class="name_zelle">
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=87823ec0e2b3da9441a6bc372c191538">Dr. med. Kathrin Ronel</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Innere Medizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody></table>
#  <br/>
#  <hr/>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Palliativmedizin
#                                      <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  <table class="name_tabelle">
#  <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody></table>
#  </td>, <table class="name_tabelle">
#  <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=87823ec0e2b3da9441a6bc372c191538">Dr. med. Kathrin Ronel</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Innere Medizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody></table>, <tbody><tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=87823ec0e2b3da9441a6bc372c191538">Dr. med. Kathrin Ronel</a>
#  </td>
#  </tr>
#  <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>
#  <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Innere Medizin
#
#
#
#
#
#  					</td>
#  </tr>
#  </tbody>, <tr>
#  <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=87823ec0e2b3da9441a6bc372c191538">Dr. med. Kathrin Ronel</a>
#  </td>
#  </tr>, <td class="titel_name_zelle">
#  <a href="/arztsuche/app/arztInfo.htm?arztCode=87823ec0e2b3da9441a6bc372c191538">Dr. med. Kathrin Ronel</a>
#  </td>, <a href="/arztsuche/app/arztInfo.htm?arztCode=87823ec0e2b3da9441a6bc372c191538">Dr. med. Kathrin Ronel</a>, <tr>
#  <td class="arztart_zelle">
#  							Hausarzt
#  						</td>
#  </tr>, <td class="arztart_zelle">
#  							Hausarzt
#  						</td>, <tr>
#  <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Innere Medizin
#
#
#
#
#
#  					</td>
#  </tr>, <td class="fachgebiet_zelle">
#
#
#
#  							Fachärztin für Innere Medizin
#
#
#
#
#
#  					</td>, <br/>, <hr/>, <table class="name_tabelle">
#  <tbody><tr>
#  <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Palliativmedizin
#                                      <br/>
#  </td>
#  </tr>
#  </tbody></table>, <tbody><tr>
#  <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Palliativmedizin
#                                      <br/>
#  </td>
#  </tr>
#  </tbody>, <tr>
#  <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Palliativmedizin
#                                      <br/>
#  </td>
#  </tr>, <td>
#  <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span><br/>
#
#                                      Palliativmedizin
#                                      <br/>
#  </td>, <span class="zusatzinfo_titel">Zusatzbezeichnungen:</span>, <br/>, <br/>, <table class="name_tabelle">
#  <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody></table>, <tbody><tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>
#  </tbody>, <tr>
#  <td class="nur_intern_sichtbar">
#  </td>
#  </tr>, <td class="nur_intern_sichtbar">
#  </td>, <td class="adresse_zelle">
#  <table class="adresse_tabelle">
#  <!-- im Fall von speziellen Leistungsortarten auch den Namen der Betriebsstaette hier ausgeben -->
#  <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Zweibrückenstraße 2
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>
#  </tbody></table>
#  <table class="tel_tabelle">
#  <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229009
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Fax.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229448
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                      E-Mail:
#                  </td>
#  <td>
#  <a href="mailto:info@hausarztpraxis-isartor.de">info@hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Web:
#                  </td>
#  <td>
#  <a href="http://www.hausarztpraxis-isartor.de" target="_blank">http://www.hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  </tbody></table>
#  </td>, <table class="adresse_tabelle">
#  <!-- im Fall von speziellen Leistungsortarten auch den Namen der Betriebsstaette hier ausgeben -->
#  <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Zweibrückenstraße 2
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>
#  </tbody></table>, <tbody><tr>
#  <td>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                          Zweibrückenstraße 2
#                  </td>
#  </tr>
#  <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>
#  </tbody>, <tr>
#  <td>
#  </td>
#  </tr>, <td>
#  </td>, <tr>
#  <td>
#                          Zweibrückenstraße 2
#                  </td>
#  </tr>, <td>
#                          Zweibrückenstraße 2
#                  </td>, <tr>
#  <td>
#                          80331 München
#                  </td>
#  </tr>, <td>
#                          80331 München
#                  </td>, <table class="tel_tabelle">
#  <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229009
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Fax.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229448
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                      E-Mail:
#                  </td>
#  <td>
#  <a href="mailto:info@hausarztpraxis-isartor.de">info@hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Web:
#                  </td>
#  <td>
#  <a href="http://www.hausarztpraxis-isartor.de" target="_blank">http://www.hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  </tbody></table>, <tbody><tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229009
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Fax.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229448
#
#
#                          <br/>
#  </td>
#  </tr>
#  <tr>
#  <td>
#                      E-Mail:
#                  </td>
#  <td>
#  <a href="mailto:info@hausarztpraxis-isartor.de">info@hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  <tr>
#  <td class="tel_td">
#                      Web:
#                  </td>
#  <td>
#  <a href="http://www.hausarztpraxis-isartor.de" target="_blank">http://www.hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>
#  </tbody>, <tr>
#  <td class="tel_td">
#                      Tel.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229009
#
#
#                          <br/>
#  </td>
#  </tr>, <td class="tel_td">
#                      Tel.:
#                  </td>, <td>
#
#
#
#
#                                  089-229009
#
#
#                          <br/>
#  </td>, <br/>, <tr>
#  <td class="tel_td">
#                      Fax.:
#                  </td>
#  <td>
#
#
#
#
#                                  089-229448
#
#
#                          <br/>
#  </td>
#  </tr>, <td class="tel_td">
#                      Fax.:
#                  </td>, <td>
#
#
#
#
#                                  089-229448
#
#
#                          <br/>
#  </td>, <br/>, <tr>
#  <td>
#                      E-Mail:
#                  </td>
#  <td>
#  <a href="mailto:info@hausarztpraxis-isartor.de">info@hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>, <td>
#                      E-Mail:
#                  </td>, <td>
#  <a href="mailto:info@hausarztpraxis-isartor.de">info@hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>, <a href="mailto:info@hausarztpraxis-isartor.de">info@hausarztpraxis-isartor.de</a>, <br/>, <tr>
#  <td class="tel_td">
#                      Web:
#                  </td>
#  <td>
#  <a href="http://www.hausarztpraxis-isartor.de" target="_blank">http://www.hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>
#  </tr>, <td class="tel_td">
#                      Web:
#                  </td>, <td>
#  <a href="http://www.hausarztpraxis-isartor.de" target="_blank">http://www.hausarztpraxis-isartor.de</a>
#  <br/>
#  </td>, <a href="http://www.hausarztpraxis-isartor.de" target="_blank">http://www.hausarztpraxis-isartor.de</a>, ...]

# %%
# Out:
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=1&zeigeKarte=true
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=2&zeigeKarte=true
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=3&zeigeKarte=true
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=4&zeigeKarte=true
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=5&zeigeKarte=true
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=6&zeigeKarte=true
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=7&zeigeKarte=true
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=8&zeigeKarte=true
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=9&zeigeKarte=true
# https://dienste.kvb.de/arztsuche/app/suchergebnisse.htm?hashwert=ec612783a8c5320de977f02cedce5c&lat=48.1351253&lng=11.5819805&page=10&zeigeKarte=true

# %%
driver.get(r'https://www.muenchen.de/service/branchenbuch/A/15.html')
content = driver.page_source
soup = BeautifulSoup(content)
leng = len(soup.find_all(itemprop="name"))
names = soup.find_all(itemprop="name")
addresses = soup.find_all(itemprop="streetAddress")
cities = soup.find_all(itemprop="addressLocality")
#soup.find_all('<span class="item__url item__url--address str" itemprop="streetAddress">')
#<span class="item__url item__url--address zip" itemprop="addressLocality">
outputFile = open('apotheken_muenchen.csv','w',newline='')
outputWriter = csv.writer(outputFile)
outputWriter.writerow(['Name', 'Straße', 'Ort'])

for k in range(0, len(names)):
    name = names[k].contents[0]
    name = name.strip('\n')
    name = name.strip()
    address = addresses[k].contents[0]
    address = address.strip('\n')
    address = address.strip()
    city = cities[k].contents[0]
    city = city.strip('\n')
    city = city.strip()
    outputWriter.writerow([name, address, city])

# %%
driver.get(r'https://www.muenchen.de/service/branchenbuch/A/15_2.html')
content = driver.page_source
soup = BeautifulSoup(content)
names = soup.find_all(itemprop="name")
addresses = soup.find_all(itemprop="streetAddress")
cities = soup.find_all(itemprop="addressLocality")
for k in range(0, len(names)):
    name = names[k].contents[0]
    name = name.strip('\n')
    name = name.strip()
    address = addresses[k].contents[0]
    address = address.strip('\n')
    address = address.strip()
    city = cities[k].contents[0]
    city = city.strip('\n')
    city = city.strip()
    outputWriter.writerow([name, address, city])

# %%
driver.get(r'https://www.muenchen.de/service/branchenbuch/A/15_3.html')
content = driver.page_source
soup = BeautifulSoup(content)
names = soup.find_all(itemprop="name")
addresses = soup.find_all(itemprop="streetAddress")
cities = soup.find_all(itemprop="addressLocality")
for k in range(0, len(names)):
    name = names[k].contents[0]
    name = name.strip('\n')
    name = name.strip()
    address = addresses[k].contents[0]
    address = address.strip('\n')
    address = address.strip()
    city = cities[k].contents[0]
    city = city.strip('\n')
    city = city.strip()
    outputWriter.writerow([name, address, city])
outputFile.close()

# %%
outputFile.close()
