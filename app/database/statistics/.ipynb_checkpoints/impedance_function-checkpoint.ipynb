# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from scipy.optimize import curve_fit
from scipy import optimize
from lmfit.models import StepModel, LinearModel
from sklearn.metrics import r2_score

# %%
def gaus(x, b):
    return (np.exp(-((x)**2)/b))
def exp(x, b):
    return(np.exp(x*b))
def exp2(x, a, b):
    return(a*np.exp(b*x))
def pow(x, a):
    return(x**(-a))

# %%
#Daily Goods
x = np.array([0.000001, 375, 750, 1500, 3750])
x2 = np.array([0.000001,187.5,562.5,1125,2625])
y = np.array([1, 0.81, 0.57, 0.21, 0.05])

#Gaussian Function
beta1 = optimize.curve_fit(gaus, xdata = x2, ydata = y, p0 = 40000)[0]
print('Gaussian Function')
print(f'beta = {beta1[0]}')
print('R2 = ', r2_score(y, gaus(x2,*beta1)))

#Exponential Function 1
alpha2 = optimize.curve_fit(exp, xdata = x2, ydata = y, p0 = 0.01)[0]
print('Exponential Function')
print(f'alpha = {alpha2[0]}')
print('R2 = ', r2_score(y, exp(x2,*alpha2)))

#Exponential Function 2
alpha3, beta3 = optimize.curve_fit(exp2, xdata = x2, ydata = y, p0 = (5.0,0.01))
alpha3a = alpha3[0]
print('Modified Exponential Function')
print(f'alpha = {alpha3[0]}', f'beta = {alpha3[1]}')
print('R2 = ', r2_score(y, exp2(x2,alpha3[0],alpha3[1])))

#plot Graphs
xmin, xmax = 0, 6000
a = plt.figure(num=1,dpi=500)
points = 1000
axes = a.add_axes([0.1,0.1,0.8,0.8])
axes.set_xlim([0,6000])
axes.set_ylim([0,1])
x2 = np.array([0,187.5,562.5,1125,2625])
y = np.array([1, 0.81, 0.57, 0.21, 0.05])
#plt.step(x1, y, where='pre')
plt.plot(x2, y, 'o--', color='grey', alpha=0.3)
plt.title(label='Daily Goods')
axes.set_xlabel('Time [s]')
axes.set_ylabel('Percentage of Accessibility')
axes.grid(True, color ='#EEEEEE')
x = np.linspace(xmin, xmax, points)
plt.plot(x, gaus(x, beta1), label = 'Modified Gaussian')
plt.plot(x, exp(x, alpha2), label = 'Exponential')
plt.plot(x, exp2(x, alpha3[0], alpha3[1]), label = 'Modified Exponential')
#plt.plot(x, pow(x, alpha4[0][0]), label = 'Power')
plt.legend(loc='upper right')
plt.show()
# Out:
# Gaussian Function
# beta = 642159.7232593967
# R2 =  0.9560297078140497
# Exponential Function
# alpha = -0.0011738113143783312
# R2 =  0.9902766871793163
# Modified Exponential Function
# alpha = 1.0132371027449607 beta = -0.0011952482063222615
# R2 =  0.9906640087663888

# %%
#Erledigung (Doctor, Pharmacy)
x = np.array([0.000001, 375, 750, 1500, 3750])
x2 = np.array([0.000001,187.5,562.5,1125,2625, 5600])
y = np.array([1, 0.77, 0.51, 0.30, 0.08, 0.01])

#Gaussian Function
beta1 = optimize.curve_fit(gaus, xdata = x2, ydata = y, p0 = 40000)[0]
print('Gaussian Function')
print(f'beta = {beta1[0]}')
print('R2 = ', r2_score(y, gaus(x2,*beta1)))

#Exponential Function 1
alpha2 = optimize.curve_fit(exp, xdata = x2, ydata = y, p0 = 0.01)[0]
print('Exponential Function')
print(f'alpha = {alpha2[0]}')
print('R2 = ', r2_score(y, exp(x2,*alpha2)))

#Exponential Function 2
alpha3, beta3 = optimize.curve_fit(exp2, xdata = x2, ydata = y, p0 = (0.001,0.001))
alpha3a = alpha3[0]
print('Modified Exponential Function')
print(f'alpha = {alpha3[0]}', f'beta = {alpha3[1]}')
print('R2 = ', r2_score(y, exp2(x2,alpha3[0],alpha3[1])))

#plot Graphs
xmin, xmax = 0, 6000
a = plt.figure(num=1,dpi=500)
points = 1000
axes = a.add_axes([0.1,0.1,0.8,0.8])
axes.set_xlim([0,6000])
axes.set_ylim([0,1])
x2 = np.array([0,187.5,562.5,1125,2625, 5600])
y = np.array([1, 0.77, 0.51, 0.30, 0.08, 0.01])
#plt.step(x1, y, where='pre')
plt.plot(x2, y, 'o--', color='grey', alpha=0.3),
plt.title(label='Doctors/Pharmacies')
axes.set_xlabel('Time [s]')
axes.set_ylabel('Percentage of Accessibility')
axes.grid(True, color ='#EEEEEE')
x = np.linspace(xmin, xmax, points)
plt.plot(x, gaus(x, beta1), label = 'Modified Gaussian')
plt.plot(x, exp(x, alpha2), label = 'Exponential')
plt.plot(x, exp2(x, alpha3[0], alpha3[1]), label = 'Modified Exponential')
plt.legend(loc='upper right')
plt.show()
# Out:
# Gaussian Function
# beta = 671036.9499552576
# R2 =  0.9034194621239512
# Exponential Function
# alpha = -0.0011378046958963812
# R2 =  0.9958515576352023
# Modified Exponential Function
# alpha = 0.9765294630471427 beta = -0.0010968738163644953
# R2 =  0.9968441709060185

# %%
#Education
x = np.array([0.000001, 375, 750, 1500, 3750])
x2 = np.array([0.000001,187.5,562.5,1125,2625])
y = np.array([1, 0.79, 0.52, 0.20, 0.02])

#Gaussian Function
beta1 = optimize.curve_fit(gaus, xdata = x2, ydata = y, p0 = 40000)[0]
print('Gaussian Function')
print(f'beta = {beta1[0]}')
print('R2 = ', r2_score(y, gaus(x2,*beta1)))

#Exponential Function 1
alpha2 = optimize.curve_fit(exp, xdata = x2, ydata = y, p0 = 0.01)[0]
print('Exponential Function')
print(f'alpha = {alpha2[0]}')
print('R2 = ', r2_score(y, exp(x2,*alpha2)))

#Exponential Function 2
alpha3, beta3 = optimize.curve_fit(exp2, xdata = x2, ydata = y, p0 = (0.01,0.01))
alpha3a = alpha3[0]
print('Modified Exponential Function')
print(f'alpha = {alpha3[0]}', f'beta = {alpha3[1]}')
print('R2 = ', r2_score(y, exp2(x2,alpha3[0],alpha3[1])))


#plot Graphs
xmin, xmax = 0, 6000
a = plt.figure(num=1,dpi=500)
points = 1000
axes = a.add_axes([0.1,0.1,0.8,0.8])
axes.set_xlim([0,6000])
axes.set_ylim([0,1])
x2 = np.array([0,187.5,562.5,1125,2625,5600])
y = np.array([1,0.79,0.52,0.20,0.02,0.01])
#plt.step(x1, y, where='pre')
plt.plot(x2, y, 'o--', color='grey', alpha=0.3)
plt.title(label='Education')
axes.set_xlabel('Time [s]')
axes.set_ylabel('Percentage of Accessibility')
axes.grid(True, color ='#EEEEEE')
x = np.linspace(xmin, xmax, points)
plt.plot(x, gaus(x, beta1), label = 'Modified Gaussian')
plt.plot(x, exp(x, alpha2), label = 'Exponential')
plt.plot(x, exp2(x, alpha3[0], alpha3[1]), label = 'Modified Exponential')
plt.legend(loc='upper right')
plt.show()
# Out:
# Gaussian Function
# beta = 551703.8697223967
# R2 =  0.9479053612566005
# Exponential Function 1
# alpha = -0.0012886432823214344
# R2 =  0.9959006707373733
# Exponential Function 2
# alpha = 1.00900494729759 beta = -0.0013041838488128436
# R2 =  0.9960696440373938
