# %%
from bs4 import BeautifulSoup
import pandas 
from selenium import webdriver
import openpyxl
import csv
import os
import re

print('import of modules successful')
os.chdir(r'C:\Users\sebas\Documents\Privat\Uni\Umweltingenieurwesen\Masterarbeit')
# Out:
# import of modules successful

# %%
driver = webdriver.Firefox(executable_path=r'C:\Users\sebas\Documents\Privat\Uni\Umweltingenieurwesen\Masterarbeit\WebScraping\geckodriver.exe')
driver
# Out:
# <selenium.webdriver.firefox.webdriver.WebDriver (session="4adf7832-4af1-4be7-89da-b9c585f9a370")>

# %%
driver.get(r'https://www.muenchen.de/service/branchenbuch/A/15.html')
results = []
content = driver.page_source
soup = BeautifulSoup(content)
#for element in soup.findAll(attrs={'a class': 'name'}):
#    name = element.find('a')
#    results.append(name.text)
    
#results
print(soup.prettify())
# Out:
# <html class="js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage no-websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients no-cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths" lang="de" style="">
#  <!--<![endif]-->
#  <head id="www-muenchen-de">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    Apotheke München auf muenchen.de - das offizielle Stadtportal
#   </title>
#   <meta content="TxPrchoo64RTZbfWQgV32EXS8hqib3DYV9_VqMDOnv4" name="google-site-verification"/>
#   <meta class="swiftype" content="31" data-type="integer" name="content-priority"/>
#   <meta content="muenchen.de" name="author"/>
#   <meta content="Copyright muenchen.de. All Rights Reserved." name="copyright"/>
#   <meta content="index,follow" name="robots"/>
#   <meta class="swiftype" content="Apotheke München auf muenchen.de" data-type="string" name="keywords"/>
#   <meta class="swiftype" content="Apotheke München auf muenchen.de, 631 Einträge im offiziellen Stadtportal. Mit Telefonnummern, Adressen, Stadtplan und Fahrplanauskunft." data-type="string" name="description"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/media/css/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/media/css/images/favicon32.png" rel="icon" type="image/png"/>
#   <link href="/media/css/images/favicon32.png" rel="shortcut icon" type="image/png"/>
#   <link href="/media/css/images/favicon_114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="/media/css/images/favicon_72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="/media/css/images/favicon_57x57.png" rel="apple-touch-icon-precomposed"/>
#   <meta content="" property="og:title"/>
#   <meta content="city" property="og:type"/>
#   <meta class="swiftype" content="http://www.muenchen.de/media/pm/logos/og_sharing.png" data-type="enum" name="image" property="og:image"/>
#   <meta content="Apotheke München auf muenchen.de, 631 Einträge im offiziellen Stadtportal. Mit Telefonnummern, Adressen, Stadtplan und Fahrplanauskunft." property="og:description"/>
#   <meta content="muenchen.de" property="og:site_name"/>
#   <meta content="100003051870766" property="fb:admins"/>
#   <link href="https://www.muenchen.de/service/branchenbuch/A/15.html" rel="canonical"/>
#   <link href="https://cdn.muenchen-p.de/raw/upload/v1536140107/mde_20180905_4.2.7hf.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <style type="text/css">
#    /* mobile search broken */
# .header__content #button-search.button--mobile { display: none !important; }
# /* mobile search broken */
#
# .m-search .m-search__form .m-search__input {
#     float: left;
#     width: 80% !important;
#     height: 32px;
#     font-size: 14px;
#   }
# .m-search .m-search__form .m-search__submit {
#     display: block;
#     content: "";
#     position: relative;
#     float: right;
#     width: 20% !important;
#     height: 32px;
#     margin: 0;
#     padding: 0;
#     border: 0 none !important;
#     border-radius: 0;
#     border-top-right-radius: 5px !important;
#     border-bottom-right-radius: 5px !important;
#     text-decoration: none;
#     text-align: center;
#     text-indent: -999rem;
#     -webkit-transition: all .2s ease-in-out;
#     -moz-transition: all .2s ease-in-out;
#     -ms-transition: all .2s ease-in-out;
#     -o-transition: all .2s ease-in-out;
#     transition: all .2s ease-in-out;
#     background: #005a9f url(https://cdn.muenchen-p.de/resources/mdeTemplates/css/images/search_box_icon.png) no-repeat center center;
#   }
# .m-search .m-search__form .m-search__input__reset,
# .m-search .m-search__form .m-search__submit span {
#     display: none;
# }
#
# .m-search .m-search__form .m-search__input__reset {
#   display: none;
#   position: absolute;
#   right: 21%;
#   top: 6px;
#   width: 20px;
#   height: 20px;
#   background-color: #fff;
#   z-index: 2;
#   cursor: pointer;
# }
# .m-search .m-search__form .m-search__input__reset.is-visible { display: block; }
# .m-search .m-search__form .m-search__input__reset:after {
#     content: '';
#     height: 20px;
#     border-left: 2px solid #333;
#     position: absolute;
#     transform: rotate(45deg);
#     left: 10px;
# }
#
# .m-search .m-search__form .m-search__input__reset:before {
#     content: '';
#     height: 20px;
#     border-left: 2px solid #333;
#     position: absolute;
#     transform: rotate(-45deg);
#     left: 10px;
# }
#
#
# .m-search .m-search__headline,
# .m-search .m-search__description {
#   padding: 0 20px;
# }
#
# .m-search:not([data-viewmode="0"]) .m-search__results { display: none; }
# .m-search:not([data-viewmode="0"]) .m-search__results.is-visible { display: block; }
#
# .m-search[data-viewmode="0"] .m-search__results .m-search__results__empty { padding: 0 20px; }
#
# .m-search .m-search__results .m-search__results__item {
#     padding: 10px 20px;
#     border-bottom: 1px solid #e0e0e0;
#     margin-bottom: 0;
#     cursor: pointer;
# }
# .m-search .m-search__results .m-search__results__item__title {
#     font-size: 16px;
#     color: #005a9f;
# }
# .m-search .m-search__results .m-search__results__item__description {
#    margin: 0;
#    color: #333;
# }
# .m-search .m-search__results .m-search__results__item__link,
# .m-search .m-search__results .m-search__results__item__link:hover {
#     display: block;
#     background-color: #fff !important;
# }
# .m-search .m-search__results .m-search__results__item__link span {
#   color: #009933;
# }
# .m-search[data-viewmode="1"] .m-search__disclaimer {
#   display: none;
# }
#
# .m-search__input__remove {
#   display: none;
# }
#
# .m-search__input__remove.is-visible {
#   display: block;
#   position: absolute;
#   top: 15px;
#   right: 15px;
#   font-size: 20px;
# }
#
# /* header search */
# #m-search_0 {
#     position: relative;
#     z-index: 300;
# }
# #m-search_0 .m-search__form {
#     position: relative;
#     height: 32px;
# }
# #m-search_0 .m-search__results.is-visible {
#     position: absolute;
#     top: 34px;
#     right: 0;
#     background: #fff;
#     min-width: 300px;
#     max-width: 320px;
#     border: 1px solid #e0e0e0;
# }
# #m-search_0 .m-search__results li {
#     padding: 4px 16px;
# }
#
# /* sticky header search */
# #m-search_3 {
#     position: relative;
#     z-index: 300;
# }
# #m-search_3 .m-search__results.is-visible {
#     position: absolute;
#     top: 34px;
#     right: 0;
#     background: #fff;
#     min-width: 300px;
#     max-width: 320px;
#     border: 1px solid #e0e0e0;
# }
# #m-search_3 .m-search__results li {
#     padding: 4px 16px;
# }
#
# /* mobile search */
# #m-search_2 {
#     padding: 0;
# }
# #m-search_2 .m-search__form {
#     padding: 20px;
#     overflow: hidden;
# }
#
# /* volltextsuche */
# #m-search_1 {
#     padding-top: 20px;
# }
#
# #m-search_1 .m-search__input {
#   margin: 0 20px;
#   width: calc(100% - 40px);
# }
#
# #m-search_1 .m-search__results {
#    padding: 20px;
#    margin-right: -20px;
#    margin-left: -20px;
# }
#
# #m-search_1 .m-search__disclaimer {
#   padding: 20px;
# }
#
# /* pagination */
# .m-search__pagination {
#   display: flex;
#   flex-wrap: wrap;
#   position: relative;
#   border-bottom: 1px solid #e0e0e0;
#   background: #f1f1f1;
# }
# .m-search__pagination li {
#   border-right: 1px solid #e0e0e0;
#   border-top: 2px solid #005a9f;
#   background-color: #fff;
#   padding: 8px 0;
#   font-size: 1rem;
#   margin: 0;
#   cursor: pointer;
#   color: #ccc;
#   width: 4%;
#   text-align: center;
# }
# .m-search__pagination li:hover {
#   color: #333;
# }
# .m-search__pagination li.is-active {
#   border-top: 2px solid #ffe400;
#   color: #333;
# }
#   </style>
#   <script charset="UTF-8" src="https://cdn.muenchen-p.de/raw/upload/v1482334800/resources/plugins_20161221.min.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://www.muenchen.de/resources/mdeTemplates/js/script_20210414.min.js" type="text/javascript">
#   </script>
#   <!-- <script src="https://cdn.muenchen-p.de/raw/upload/v1618409899/script_4.3.4.min_usq1dy.js" type="text/javascript"></script> -->
#   <style type="text/css">
#    .uc-banner-content,
#       #uc-banner-modal,
#       #usercentrics-button{
#         display: none;
#       }
#   </style>
#   <!-- usercentrics -->
#   <script id="LQhLq5nIk" src="https://app.usercentrics.eu/latest/main.js" type="application/javascript">
#   </script>
#   <script async="" src="https://app.usercentrics.eu/latest/bundle.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $( "#button-search-consent-fallback" ).unbind( "click" );
#   </script>
#   <style type="text/css">
#    twitter-widget { margin: 0 auto; }
#       img[src="https://cdn.muenchen-p.de/image/fetch/w_1180/https://www.muenchen.de"] {display:none;}
#   </style>
#   <style type="text/css">
#    /* start: cookie consent styles*/
# div.embedCodeHidden {
#    display: none;
#    visibility: hidden;
#    height: 0;
#    overflow: hidden;
# }
#
# .feed-consent {
#    padding: 0 16px;
# }
#
# .container--youtube .feed-consent {
#    padding: 0;
# }
#
# .feed-consent>.feed-consent__body {
#    position: relative;
#    -webkit-box-shadow: 0 5px 10px rgba(0, 90, 159, .2);
#    -moz-box-shadow: 0 5px 10px rgba(0, 90, 159, .2);
#    box-shadow: 0 5px 10px rgba(0, 90, 159, .2);
#    padding: 2rem 2rem 2rem 7rem;
#    background-color: #fff;
#    max-width: 800px;
#    margin: 32px auto;
# }
#
# .container--youtube .feed-consent .feed-consent__body {
#    margin-top: 0;
#    margin-bottom: 0;
# }
#
# .feed-consent .twitter-tweet,
# .feed-consent iFrame,
# .feed-consent iframe {
#    width: 100%;
#    max-width: 800px;
#    margin: 0 auto 12px auto !important;
# }
#
# .feed-consent h3,
# .feed-consent p {
#    margin: 0 0 1rem 0
# }
#
# .feed-consent p,
# .feed-consent a {
#    font-size: 14px;
#    line-height: 1.5
# }
#
# .feed-consent img {
#    position: absolute;
#    top: 2rem;
#    left: 2rem;
#    width: 52px;
#    height: 52px;
# }
#
# .feed-consent a {
#    display: inline-block;
#    border: 2px solid transparent;
#    font-size: 14px;
#    font-family: 'Open Sans';
#    font-weight: 700;
#    color: #fff !important;
#    text-decoration: none;
#    padding: 8px;
#    transition: background-color .3s;
#    background-color: #005A9F;
#    text-transform: uppercase;
# }
#
# .feed-consent a:hover {
#    background-color: #ffe400;
#    color: #525252 !important;
#    cursor: pointer;
#    border-color: #525252;
# }
# /* end: cookie consent styles*/
# @media screen and (min-width:650px) {
#  .header__content .wrap-inner {
#     height:70px;
#     background-size: 105px 70px;
#     padding: 1em 1em 1em 10em;
#  }
# }
#   </style>
#   <script>
#    var googletag = googletag || { };
#     googletag.cmd = googletag.cmd || [];
#
#     var embedCodes = [];
#   </script>
#   <!-- etPagename:  -->
#   <!-- contentTtile:  -->
#   <!-- OpendiTitle: Apotheke München auf muenchen.de - das offizielle Stadtportal -->
#   <!-- etrackerTitle: Apotheke München auf muenchen.de - das offizielle Stadtportal -->
#   <!-- BEGIN etracker Tracklet 4.0.20160201 sync -->
#   <script type="text/javascript">
#    var et_pagename = "Apotheke München auf muenchen.de - das offizielle Stadtportal";
#     var et_areas = "MDE/de/service/branchenbuch/A/15,redaktionelle Seite,Desktop";
#     var et_target = "";
#     var _btNoJquery = true;
#     var _etr = {
#       blockDC: true
#     };
#   </script>
#   <script charset="UTF-8" data-block-cookies="true" data-respect-dnt="true" data-secure-code="Shbe3K" id="_etLoader" src="https://static.etracker.com/code/e.js" type="text/javascript">
#   </script>
#   <script async="" charset="UTF-8" id="_etCode" src="//code.etracker.com/t.js?v=b62081&amp;et=Shbe3K" type="text/javascript">
#   </script>
#   <noscript>
#    <link href="https://www.etracker.de/cnt_css.php?et=Shbe3K&amp;v=4.0&amp;java=n&amp;et_easy=0&amp;et_pagename=Apotheke München auf muenchen.de - das offizielle Stadtportal&amp;et_areas=MDE/de/service/branchenbuch/A/15,redaktionelle Seite,Desktop&amp;et_ilevel=0&amp;et_target=,0,0,0&amp;et_lpage=0&amp;et_trig=0&amp;et_se=0&amp;et_cust=0&amp;et_basket=&amp;et_url=&amp;et_tag=&amp;et_sub=&amp;et_organisation=&amp;et_demographic=" media="all" rel="stylesheet"/>
#   </noscript>
#   <!-- BEGIN etracker Tracklet 4.0.20160201 sync -->
#   <script type="text/javascript">
#    function trackPrint(category, objekt, action) {
#       ET_Event.eventStart('Drucken', 'Apotheke München auf muenchen.de - das offizielle Stadtportal', 'Seite wurde gedruckt');
#     }
#     function trackEvent(category, objekt, action) {
#       ET_Event.eventStart(category, objekt, action);
#     }
#     $(document).ready(function() {
#       $('a[href^="http"]').each(function(i) {
#         $(this).click(function(event) {
#           var category = $(this).attr('data-etCategory');
#           if(category) {
#             trackEvent(category, 'Apotheke München auf muenchen.de - das offizielle Stadtportal', $(this).attr('href'));
#           } else {
#             trackEvent('Ext_Link', 'Apotheke München auf muenchen.de - das offizielle Stadtportal', $(this).attr('href'));
#           }
#         })
#       });
#     });
#   </script>
#   <meta content="A+b/H0b8RPXNaJgaNFpO0YOFuGK6myDQXlwnJB3SwzvNMfcndat4DZYMrP4ClJIzYWo3/yP2S+8FTZ/lpqbPAAEAAABueyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiVHJ1c3RUb2tlbnMiLCJleHBpcnkiOjE2MjYyMjA3OTksImlzVGhpcmRQYXJ0eSI6dHJ1ZX0=" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="A7+rMYR5onPnACrz+niKSeFdH3xw1IyHo2AZSHmxrofRk9w4HcQPMYcpBUKu6OQ6zsdxf4m/vqa6tG6Na4OLpAQAAAB4eyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiQ29udmVyc2lvbk1lYXN1cmVtZW50IiwiZXhwaXJ5IjoxNjI2MjIwNzk5LCJpc1RoaXJkUGFydHkiOnRydWV9" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2021052601.js">
#   </script>
#   <script src="https://www.google.com/cse/static/element/323d4b81541ddb5b/cse_element__de.js?usqp=CAI%3D" type="text/javascript">
#   </script>
#   <link href="https://www.google.com/cse/static/element/323d4b81541ddb5b/default+de.css" rel="stylesheet" type="text/css"/>
#   <link href="https://www.google.com/cse/static/style/look/v4/default.css" rel="stylesheet" type="text/css"/>
#   <style type="text/css">
#    .gsc-control-cse{font-family:arial, sans-serif}.gsc-control-cse .gsc-table-result{font-family:arial, sans-serif}.gsc-refinementsGradient{background:linear-gradient(to left,rgba(255,255,255,1),rgba(255,255,255,0))}.gsc-control-cse{border-color:#FFFFFF;background-color:#FFFFFF}input.gsc-input,.gsc-input-box,.gsc-input-box-hover,.gsc-input-box-focus{border-color:#E0E0E0}.gsc-search-button-v2,.gsc-search-button-v2:hover,.gsc-search-button-v2:focus{border-color:#005A9F;background-color:#005A9F;background-image:none;filter:none}.gsc-search-button-v2 svg{fill:#FFFFFF}.gsc-tabHeader.gsc-tabhActive,.gsc-refinementHeader.gsc-refinementhActive{color:#CCCCCC;border-color:#CCCCCC;background-color:#FFFFFF}.gsc-tabHeader.gsc-tabhInactive,.gsc-refinementHeader.gsc-refinementhInactive{color:#CCCCCC;border-color:#CCCCCC;background-color:#FFFFFF}.gsc-webResult.gsc-result,.gsc-results .gsc-imageResult{border-color:#FFFFFF;background-color:#FFFFFF}.gsc-webResult.gsc-result:hover{border-color:#FFFFFF;background-color:#FFFFFF}.gs-webResult.gs-result a.gs-title:link,.gs-webResult.gs-result a.gs-title:link b,.gs-imageResult a.gs-title:link,.gs-imageResult a.gs-title:link b{color:#005A9F}.gs-webResult.gs-result a.gs-title:visited,.gs-webResult.gs-result a.gs-title:visited b,.gs-imageResult a.gs-title:visited,.gs-imageResult a.gs-title:visited b{color:#1B98D5}.gs-webResult.gs-result a.gs-title:hover,.gs-webResult.gs-result a.gs-title:hover b,.gs-imageResult a.gs-title:hover,.gs-imageResult a.gs-title:hover b{color:#005A9F}.gs-webResult.gs-result a.gs-title:active,.gs-webResult.gs-result a.gs-title:active b,.gs-imageResult a.gs-title:active,.gs-imageResult a.gs-title:active b{color:#005A9F}.gsc-cursor-page{color:#005A9F}a.gsc-trailing-more-results:link{color:#005A9F}.gs-webResult:not(.gs-no-results-result):not(.gs-error-result) .gs-snippet,.gs-fileFormatType{color:#333333}.gs-webResult div.gs-visibleUrl{color:#009933}.gs-webResult div.gs-visibleUrl-short{color:#009933}.gsc-cursor-box{border-color:#FFFFFF}.gsc-results .gsc-cursor-box .gsc-cursor-page{border-color:#CCCCCC;background-color:#FFFFFF;color:#CCCCCC}.gsc-results .gsc-cursor-box .gsc-cursor-current-page{border-color:#CCCCCC;background-color:#FFFFFF;color:#CCCCCC}.gsc-webResult.gsc-result.gsc-promotion{border-color:#F6F6F6;background-color:#F6F6F6}.gsc-completion-title{color:#005A9F}.gsc-completion-snippet{color:#333333}.gs-promotion a.gs-title:link,.gs-promotion a.gs-title:link *,.gs-promotion .gs-snippet a:link{color:#1155CC}.gs-promotion a.gs-title:visited,.gs-promotion a.gs-title:visited *,.gs-promotion .gs-snippet a:visited{color:#1155CC}.gs-promotion a.gs-title:hover,.gs-promotion a.gs-title:hover *,.gs-promotion .gs-snippet a:hover{color:#1155CC}.gs-promotion a.gs-title:active,.gs-promotion a.gs-title:active *,.gs-promotion .gs-snippet a:active{color:#1155CC}.gs-promotion .gs-snippet,.gs-promotion .gs-title .gs-promotion-title-right,.gs-promotion .gs-title .gs-promotion-title-right *{color:#333333}.gs-promotion .gs-visibleUrl,.gs-promotion .gs-visibleUrl-short{color:#009933}.gcsc-find-more-on-google{color:#005A9F}.gcsc-find-more-on-google-magnifier{fill:#005A9F}
#   </style>
#  </head>
#  <body data-template="dynamicNoMargin" id="seitenanfang">
#   <a name="startseite">
#   </a>
#   <!--[if lt IE 9]>
#   <p class="chromeframe">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade
#     your browser</a> or <a href="http://www.google.com/chromeframe/?redirect=true">activate Google Chrome Frame</a> to
#     improve your experience.</p>
#   <![endif]-->
#   <div id="wrapper">
#    <div class="language-switch-mobile">
#     <div class="lmcontainer">
#      <div class="lmcontainer__item">
#       <a class="en" href="http://www.muenchen.de/int/en">
#       </a>
#      </div>
#      <div class="lmcontainer__item">
#       <a class="fr" href="http://www.muenchen.de/int/fr/">
#       </a>
#      </div>
#      <div class="lmcontainer__item">
#       <a class="it" href="http://www.muenchen.de/int/it/">
#       </a>
#      </div>
#      <div class="lmcontainer__item">
#       <a class="ru" href="http://www.muenchen.de/int/ru/">
#       </a>
#      </div>
#      <div class="lmcontainer__item">
#       <a class="ar" href="http://www.muenchen.de/int/ar/">
#       </a>
#      </div>
#      <div class="lmcontainer__item">
#       <a class="zh" href="http://www.muenchen.de/int/zh/">
#       </a>
#      </div>
#     </div>
#    </div>
#    <header class="header sticky" data-swiftype-index="false" role="header">
#     <section class="white header__topnav">
#      <div class="wrap-inner">
#       <div class="left">
#        <nav class="topnav" itemscope="" itemtype="http://schema.org/SiteNavigationElement">
#         <a class="topnav__item wetterwidget wetterwidget--6" href="https://www.muenchen.de/freizeit/wetter-aktuell-muenchen.html">
#          16 °C
#         </a>
#         <a class="topnav__item" href="https://www.muenchen.de/stadtteile.html">
#          Stadtteil
#         </a>
#         <a class="topnav__item show-for-large-only" href="https://www.muenchen.de/landkreise.html">
#          Landkreise
#         </a>
#         <a class="topnav__item" href="https://www.muenchen.de/umland.html">
#          Umland
#         </a>
#         <a class="topnav__item" href="https://www.muenchen.de/sehenswuerdigkeiten/webcam.html">
#          Webcam
#         </a>
#         <a class="topnav__item" href="https://app.muenchen.de/stadtplan" target="_blank">
#          Stadtplan
#         </a>
#         <a class="topnav__item" href="https://www.muenchen.de/verkehr/elektronische-auskunft/fahrplanauskunft-efa.html">
#          Fahrplan
#         </a>
#        </nav>
#       </div>
#       <div class="right">
#        <nav class="topnav" itemscope="" itemtype="http://schema.org/SiteNavigationElement">
#         <a class="topnav__item newsletterlink show-for-large-only" href="https://www.muenchen.de/newsletter.html?et_cid=33&amp;et_lid=7750175" title="Der muenchen.de E-Mail Newsletter">
#          Newsletter
#         </a>
#         <a class="topnav__item applink" href="https://www.muenchen.de/meta/iphone-android-app.html" title="München als App downloaden">
#          App
#         </a>
#         <div class="language-dropdown left" role="navigation">
#          <a class="language-dropdown__item language-dropdown__trigger language-dropdown__trigger--de" data-etcategory="header-int-de" href="//www.muenchen.de/int/" title="International">
#           <span>
#            International
#           </span>
#          </a>
#          <div class="language-dropdown__content">
#           <a class="language-dropdown__item language-dropdown__item--en" href="//www.muenchen.de/int/en/">
#            English
#           </a>
#           <a class="language-dropdown__item language-dropdown__item--fr" href="//www.muenchen.de/int/fr/">
#            Français
#           </a>
#           <a class="language-dropdown__item language-dropdown__item--it" href="//www.muenchen.de/int/it/">
#            Italiano
#           </a>
#           <a class="language-dropdown__item language-dropdown__item--ru" href="//www.muenchen.de/int/ru/">
#            Русский
#           </a>
#           <a class="language-dropdown__item language-dropdown__item--ar" href="//www.muenchen.de/int/ar/">
#            العربية
#           </a>
#           <a class="language-dropdown__item language-dropdown__item--zh" href="//www.muenchen.de/int/zh/">
#            中文
#           </a>
#          </div>
#         </div>
#        </nav>
#       </div>
#      </div>
#     </section>
#     <style type="text/css">
#      .header__content #button-search-consent-fallback {
#     float: right;
#   border: 0;
#   color: #fff;
#   width: 3em;
#   height: 3em;
#   overflow: hidden;
#   padding: 0;}
#     </style>
#     <section class="turquoise header__content">
#      <div class="wrap-inner">
#       <a class="button button--mobile left show-for-small-only" href="#" id="button-menu">
#        <img alt="" src="https://cdn.muenchen-p.de/resources/mdeTemplates/css/images/button_menu-2x.png"/>
#       </a>
#       <a class="button button--mobile right show-for-small-only" href="#" id="button-search">
#        <img alt="" src="https://cdn.muenchen-p.de/resources/mdeTemplates/css/images/button_search-yellow-2x.png"/>
#       </a>
#       <a class="show-for-small-only" href="https://www.muenchen.de/volltextsuche.html" id="button-search-consent-fallback">
#        <img alt="" src="https://cdn.muenchen-p.de/resources/mdeTemplates/css/images/button_search-yellow-2x.png"/>
#       </a>
#       <a alt="" class="logo" href="//www.muenchen.de/">
#        <img alt="muenchen.de - das offizielle Stadtportal" src="https://cdn.muenchen-p.de/resources/mdeTemplates/css/images/muenchende.png"/>
#       </a>
#       <div class="header__search-box m-search is-type--autocomplete" data-componentindex="0" data-viewmode="1" id="m-search_0">
#        <form action="/volltextsuche.html" class="m-search__form" id="m-search__form0">
#         <input autocomplete="off" class="m-search__input" id="m-search__input0" name="query" placeholder="Suche" type="text"/>
#         <span class="m-search__input__reset" id="m-search__input__reset0">
#         </span>
#         <button class="m-search__submit" id="m-search__submit0" type="submit">
#          S
#         </button>
#        </form>
#        <div class="m-search__results" id="m-search__results0">
#         <ul class="m-search__results__content" id="m-search__results__content0">
#         </ul>
#        </div>
#       </div>
#       <div class="show-for-sticky right">
#        <div class="header__search-box--sticky left" data-componentindex="3" id="m-search_3">
#        </div>
#        <div class="language-dropdown left" role="navigation">
#         <a class="language-dropdown__item language-dropdown__trigger language-dropdown__trigger--de" data-etcategory="header-int-de" href="//www.muenchen.de/int/" title="International">
#          <span>
#           International
#          </span>
#         </a>
#         <div class="language-dropdown__content">
#          <a class="language-dropdown__item language-dropdown__item--en" href="//www.muenchen.de/int/en/">
#           English
#          </a>
#          <a class="language-dropdown__item language-dropdown__item--fr" href="//www.muenchen.de/int/fr/">
#           Français
#          </a>
#          <a class="language-dropdown__item language-dropdown__item--it" href="//www.muenchen.de/int/it/">
#           Italiano
#          </a>
#          <a class="language-dropdown__item language-dropdown__item--ru" href="//www.muenchen.de/int/ru/">
#           Русский
#          </a>
#          <a class="language-dropdown__item language-dropdown__item--ar" href="//www.muenchen.de/int/ar/">
#           العربية
#          </a>
#          <a class="language-dropdown__item language-dropdown__item--zh" href="//www.muenchen.de/int/zh/">
#           中文
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <!-- Mainmenu -->
#     <section class="blue header__mainnav">
#      <div class="wrap-inner">
#       <nav class="mainnav">
#        <ul class="mainnav__list" role="navigation">
#         <!--<li id="mainMenuItem99999" class="mainnav__item">
#               <a href="http://www.muenchen.de" class="mainnav__home"><i class="fa fa-home" style="color:#fff;"></i></a>
#             </li>-->
#         <li class="mainnav__item" data-mdemainmenucount="0" id="mainMenuItem0">
#          <a class="" href="http://www.muenchen.de/rathaus/home.html">
#           <span>
#            Rathaus
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="1" id="mainMenuItem1">
#          <a class="" href="http://www.muenchen.de/branchenbuch">
#           <span>
#            Branchenbuch
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="2" id="mainMenuItem2">
#          <a class="" href="http://www.muenchen.de/veranstaltungen.html">
#           <span>
#            Veranstaltungen
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="3" id="mainMenuItem3">
#          <a class="" href="http://www.muenchen.de/kino.html">
#           <span>
#            Kino
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="4" id="mainMenuItem4">
#          <a class="" href="http://www.muenchen.de/freizeit.html">
#           <span>
#            Freizeit
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="5" id="mainMenuItem5">
#          <a class="" href="http://www.muenchen.de/sehenswuerdigkeiten.html">
#           <span>
#            Sehenswertes
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="6" id="mainMenuItem6">
#          <a class="" href="http://www.muenchen.de/essen-trinken.html">
#           <span>
#            Restaurants
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="7" id="mainMenuItem7">
#          <a class="" href="http://www.muenchen.de/shopping.html">
#           <span>
#            Shopping
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="8" id="mainMenuItem8">
#          <a class="" href="http://www.muenchen.de/uebernachten.html">
#           <span>
#            Hotels
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="9" id="mainMenuItem9">
#          <a class="" href="http://www.muenchen.de/verkehr.html">
#           <span>
#            Verkehr
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="10" id="mainMenuItem10">
#          <a class="" href="http://www.muenchen.de/rathaus/wirtschaft.html">
#           <span>
#            Wirtschaft
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="11" id="mainMenuItem11">
#          <a class="" href="http://www.muenchen.de/leben/job.html">
#           <span>
#            Jobs
#           </span>
#          </a>
#         </li>
#         <li class="mainnav__item" data-mdemainmenucount="12" id="mainMenuItem12">
#          <a class="" href="http://www.muenchen.de/leben.html">
#           <span>
#            Leben
#           </span>
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </section>
#     <!-- Das ist ein Test -->
#    </header>
#    <!-- corona hotfix -->
#    <style type="text/css">
#     #corona-hotline {
#   position: relative;
#   top: -8px;
#   border-bottom: 1px solid #e0e0e0;
#   background-color: #fff;
#   color: #3d3d3d;
#   font-size: .9rem;
#   font-weight: 700;
#
# }
# #corona-hotline a { display: inline-block; background-color: #b30505; color: #fff; padding: 4px 16px; }
# #corona-hotline a:hover { color: #fff; text-decoration: underline; }
# #corona-hotline .corona-hotline__body { padding: 0; }
#
# .breadcrumb #corona-hotline { none; }
# #pagecontent #corona-hotline { display: block; }
#
# @media all and (min-width: 650px) {
#   .breadcrumb #corona-hotline { block;top: -3px; }
#   #pagecontent #corona-hotline { display: none;  }
# }
# @media all and (min-width: 1180px) {
#   #corona-hotline .corona-hotline__body { padding-left: 8px; }
# }
#    </style>
#    <!-- corona hotfix -->
#    <div class="breadcrumb" data-swiftype-index="false" itemprop="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
#     <div id="corona-hotline">
#      <div class="wrap-inner">
#       <div class="corona-hotline__body">
#        <a href="https://www.muenchen.de/corona">
#         Corona: Aktuelle Infos der Stadt »
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="wrap-inner">
#      <ul class="breadcrumb__list">
#       <li class="breadcrumb__item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="https://www.muenchen.de/">
#        </a>
#       </li>
#       <li class="breadcrumb__item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="https://www.muenchen.de/branchenbuch">
#         Branchenbuch
#        </a>
#       </li>
#       <li class="breadcrumb__item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <span itemprop="item">
#         Apotheke in München
#        </span>
#        <meta content="2" itemprop="position"/>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div id="fullscreen">
#    </div>
#    <div id="canvas">
#     <style type="text/css">
#      #lucy-labeled span {color: #3d3d3d;font-weight: 700;font-size: 14px;}
#     </style>
#     <div data-swiftype-index="false" id="lucy-labeled">
#      <div class="wrap-inner">
#       <span>
#        Kunde von muenchen.de
#       </span>
#      </div>
#     </div>
#     <div class="fullsize" id="pagecontent" role="maincontent">
#      <div id="corona-hotline">
#       <div class="wrap-inner">
#        <div class="corona-hotline__body">
#         <a href="https://www.muenchen.de/corona">
#          Corona: Aktuelle Infos der Stadt »
#         </a>
#        </div>
#       </div>
#      </div>
#      <div id="pageview">
#       <div id="main">
#        <div class="card card--nostyle">
#         <div class="card__content">
#          <script type="text/javascript">
#           jQuery(document).ready(function(){
#         function showCC()
#         {
#             var ccWindow=jQuery('#anrufFenster');
#             ccWindow.find('input').prop('disabled', false)
#             ccWindow.find('.obutton').attr('value','anrufen')
#             ccWindow.find('.info').text('Geben Sie Ihre Rufnummer ein, damit wir die Verbindung herstellen können.')
#             ccWindow.removeClass('hidden');
#             jQuery('#targetId').val(jQuery(this).attr('name'));
#         }
#         jQuery('.utilCall').click(showCC);
#         jQuery('dd>span.tel').append(function(){
#             return jQuery('<a href="javascript:void(0)" name="'+jQuery(this).attr('id')+'">jetzt anrufen</a>').click(showCC);
#         });
#         jQuery('#anrufFenster .btnClose').click(function(){
#             jQuery('#anrufFenster').addClass('hidden');
#         });
#         jQuery('#anrufFenster').find('form').submit(function(){
#             var formData=jQuery(this).serializeArray();
#             var submitVal=formData[0].value+formData[1].value+','+formData[2].value;
#             try {
#                 jQuery.ajax({
#                     type:'POST',
#                     url:'https://www.muenchen.de/opendi/ajax.html',
#                     dataType:'json',
#                     data:{opComposite:'ajax',action:'callPhone',value:submitVal},
#                     beforeSend: function() {
#                         jQuery('#anrufFenster').find('input').prop('disabled', true);
#                         jQuery('#anrufFenster').find('.obutton').attr('value','verbinde..');
#                     },
#                     success: function(data) {
#                         jQuery('#anrufFenster').find('.obutton').attr('value','Rufaufbau..');
#                         jQuery('#anrufFenster').find('.status').text(data[0].displayStatus);
#                         jQuery('#anrufFenster').find('.info').text(data[0].message);
#                     }
#                 });
#             }catch(e){
#                 jQuery('#anrufFenster').find('.status').text('Fehler');
#                 jQuery('#anrufFenster').find('.info').text('Es ist ein Fehler aufgetreten. Bitte versuchen Sie es zu einem späteren Zeitpunkt erneut.');
#             }
#             return false;
#         });
#     });
#          </script>
#          <div class="modalWindow hidden" id="anrufFenster">
#           <div class="typicons-times btnClose">
#           </div>
#           <h2 class="status">
#            kostenlos anrufen
#           </h2>
#           <p class="info">
#           </p>
#           <form>
#            <input name="vorwahl" placeholder="Vorwahl" type="text"/>
#            <input name="telefon" placeholder="Telefon" type="text"/>
#            <input id="targetId" name="targetId" type="hidden" value=""/>
#            <input class="obutton" type="submit" value="anrufen"/>
#           </form>
#          </div>
#          <!-- m.de test -->
#          <script type="text/javascript">
#           // http://www.muenchen.de/opendi/branchenbuch/trefferliste.html
#          </script>
#          <style type="text/css">
#           .suggest-container__item .suggest-rating .rating-stars {
#     background: url(https://cdn.muenchen-p.de/resources/mdeTemplates/css/images/star-on.png);
# }
# .suggest-container__item:after {
#     content: "\0032";
# }
# @media screen and (min-width:650px) {
#   .suggest-container__item .suggest-rating label {
#     top: -16px;
#   }
#   .suggest-container__item .suggest-rating .rating-stars {
#     top: 0px;
#     left: 10px;
#   }
# }
#          </style>
#          <div class="searchbar" data-initbbsuggest="true">
#           <form accept-charset="UTF-8" action="https://www.muenchen.de/branchenbuch/suche.html" class="searchbar__form sb-listing" id="opendiBrancheForm">
#            <input id="industryFacetName" name="what" type="hidden" value=""/>
#            <input id="locType" name="locType" type="hidden" value=""/>
#            <input id="locOrtLinkName" name="locOrtLinkName" type="hidden" value="muenchen"/>
#            <input id="locOrtsteilLinkName" name="locOrtsteilLinkName" type="hidden" value=""/>
#            <input id="locFacetName" name="where" type="hidden" value=""/>
#            <input id="geoPos" name="geoPos" type="hidden" value=""/>
#            <input id="searchListType" name="type" type="hidden" value=""/>
#            <div class="row collapse">
#             <div class="row collapse medium-uncollapse">
#              <div class="column small-12 medium-5 large-5">
#               <div class="searchbar__form-group">
#                <label class="searchbar__label" for="sbinput-what">
#                 Was?
#                </label>
#                <input autocomplete="off" class="searchbar__input" id="sbinput-what" type="text" value="Apotheke"/>
#                <div class="autosuggest-results suggest" id="autosuggest-what-results">
#                </div>
#               </div>
#              </div>
#              <div class="column small-12 medium-4 large-5">
#               <div class="searchbar__form-group">
#                <label class="searchbar__label" for="sbinput-where">
#                 Wo?
#                </label>
#                <input autocomplete="off" class="searchbar__input" id="sbinput-where" placeholder="München" type="text" value="München"/>
#                <a class="searchbar__button-geo" href="#">
#                 <i class="icon--small icon--kompass">
#                 </i>
#                </a>
#                <div class="autosuggest-results suggest" id="autosuggest-where-results">
#                 <!-- Filled by js/modules/BranchenbuchSuggest -->
#                </div>
#               </div>
#              </div>
#              <div class="column small-12 medium-3 large-2">
#               <div class="searchbar__form-group">
#                <button class="right searchbar__button" type="submit">
#                 <span>
#                  <i class="icon left small search-white">
#                  </i>
#                  Suchen
#                 </span>
#                </button>
#               </div>
#              </div>
#             </div>
#            </div>
#           </form>
#          </div>
#          <div class="card" data-swiftype-index="false">
#           <h1 class="card__headline">
#            Apotheke München und Umgebung
#            <span class="font-default right">
#             631 Treffer
#            </span>
#           </h1>
#           <div class="card__content">
#            <div class="flexteaser-block flexteaser-block-large">
#             <a class="flexteaser flexteaser--opendi" href="https://branchenbuch.portal.muenchen.de/mhp/1215666/" style="height: 308px;" target="_blank">
#              <figure class="flexteaser__image">
#               <img alt="Internationale Ludwigs-Apotheke" class="card" height="136" src="//images.portal.muenchen.de/000/000/244/892/versions/internatludwigsapo.jpg" title="Internationale Ludwigs-Apotheke" width="300"/>
#               <noscript>
#                <img alt="Internationale Ludwigs-Apotheke" class="card" height="136" src="//images.portal.muenchen.de/000/000/244/892/versions/internatludwigsapo.jpg" title="Internationale Ludwigs-Apotheke" width="300"/>
#               </noscript>
#              </figure>
#              <div class="flexteaser__content">
#               <h3 style="font-size: 16px;">
#                Internationale Ludwigs-Apotheke
#               </h3>
#               <p style="font-size: 18px;">
#                In München Stadtmitte ca. 15.000 Medikamente/Artikel vorrätig
#                <!--<span class="more">mehr</span>-->
#               </p>
#              </div>
#             </a>
#             <a class="flexteaser flexteaser--opendi" href="https://branchenbuch.portal.muenchen.de/mhp/1350050/" style="height: 308px;" target="_blank">
#              <figure class="flexteaser__image">
#               <img alt="Apotheke zur Münchner Freiheit" class="card" height="149" src="//images.portal.muenchen.de/000/000/264/280/versions/pharmacy-thumbnail-2574136_319x149_5bc6f6be9c097.png" title="Apotheke zur Münchner Freiheit" width="319"/>
#               <noscript>
#                <img alt="Apotheke zur Münchner Freiheit" class="card" height="149" src="//images.portal.muenchen.de/000/000/264/280/versions/pharmacy-thumbnail-2574136_319x149_5bc6f6be9c097.png" title="Apotheke zur Münchner Freiheit" width="319"/>
#               </noscript>
#              </figure>
#              <div class="flexteaser__content">
#               <h3 style="font-size: 16px;">
#                Apotheke zur Münchner Freiheit
#               </h3>
#               <p style="font-size: 18px;">
#                natürlich gesund schön
#                <!--<span class="more">mehr</span>-->
#               </p>
#              </div>
#             </a>
#             <a class="flexteaser flexteaser--opendi" href="https://branchenbuch.portal.muenchen.de/mhp/1301179/" style="height: 308px;" target="_blank">
#              <figure class="flexteaser__image">
#               <img alt="Klösterl-Apotheke" class="card" height="140" src="//images.portal.muenchen.de/000/000/247/873/versions/image002_300x140_5f68b28477e9b.png" title="Klösterl-Apotheke" width="300"/>
#               <noscript>
#                <img alt="Klösterl-Apotheke" class="card" height="140" src="//images.portal.muenchen.de/000/000/247/873/versions/image002_300x140_5f68b28477e9b.png" title="Klösterl-Apotheke" width="300"/>
#               </noscript>
#              </figure>
#              <div class="flexteaser__content">
#               <h3 style="font-size: 16px;">
#                Klösterl-Apotheke
#               </h3>
#               <p style="font-size: 18px;">
#                So individuell wie Sie: Beratung und eigene Herstellung. Ihre Apotheke im Herzen Münchens
#                <!--<span class="more">mehr</span>-->
#               </p>
#              </div>
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="list-view list-view--table list-view--branchenbuch">
#           <div class="item item--premium" itemscope="" itemtype="http://schema.org/LocalBusiness">
#            <div class="item__row">
#             <div class="item__column item__column--brand">
#              <a class="item__url" href="https://branchenbuch.portal.muenchen.de/mhp/557531/">
#               <div class="logo">
#                <img alt="Logo Ambigon Apotheke München" height="25" src="https://images.portal.muenchen.de/000/000/238/752/versions/logo_Ambigon.png" width="160"/>
#               </div>
#              </a>
#             </div>
#             <div class="item__column item__column--address">
#              <a href="https://branchenbuch.portal.muenchen.de/mhp/557531/">
#               <h3 itemprop="name">
#                Ambigon Apotheke München
#                <br/>
#                Apotheke in Neuhausen
#               </h3>
#              </a>
#              <a href="https://branchenbuch.portal.muenchen.de/mhp/557531/" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#               <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#                <span class="item__url item__url--address str" itemprop="streetAddress">
#                 Rosa-Bavarese-Str. 5
#                </span>
#                <br/>
#                <span class="item__url item__url--address zip" itemprop="addressLocality">
#                 80639 München
#                </span>
#                <span class="item__url item__url--address tel" itemprop="telephone">
#                 Tel:  (089) 122809140
#                </span>
#               </div>
#              </a>
#             </div>
#             <div class="item__column item__column--info">
#              <a class="item__url item__url--tags ianchor" href="https://branchenbuch.portal.muenchen.de/mhp/557531/">
#               Babykopfkissen
#               <br/>
#               Verleih: Milchpumpen,
#               <br/>
#               Babywaagen, Inhaliergeräte
#               <br/>
#               Lieferservice
#               <br/>
#               Ernährungsberatung
#              </a>
#              <a class="item__url item__url--branch brancheLink" href="https://www.muenchen.de/service/branchenbuch/muenchen/muenchen/nymphenburg/A/15.html" title="Apotheke Nymphenburg">
#               Apotheke Nymphenburg
#              </a>
#             </div>
#             <div class="item__column item__column--utils">
#              <div class="rating" data-avgrating="0" data-numratings="0">
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <a href="https://branchenbuch.portal.muenchen.de/mhp/557531/#bewertungen">
#                (0)
#               </a>
#              </div>
#              <a class="util utilUrl" href="https://www.ambigon-apotheke.de/" itemprop="url" target="extern">
#               <i class="icon small web left">
#               </i>
#               Homepage
#              </a>
#              <a class="util utilEmail" href="mailto:info@ambigon-apotheke.de">
#               <i class="icon small mail left">
#               </i>
#               Kontakt
#              </a>
#              <div class="button-wrap">
#               <a class="button button--small" href="https://branchenbuch.portal.muenchen.de/mhp/557531/">
#                <span>
#                 Mehr Infos
#                </span>
#               </a>
#              </div>
#             </div>
#             <div class="item__meta">
#              <div class="rating" data-avgrating="0" data-numratings="0">
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <i class="icon icon--small icon--bewertungssterne">
#               </i>
#               <a href="https://branchenbuch.portal.muenchen.de/mhp/557531/#bewertungen">
# ...
#
#   } else {
#     seg.resetResultsContainer(componentIndex);
#   }
# }
#
# searchGoogleController.prototype.initPagination = function (counterFoundItemsTotal, pageIndex, componentIndex) {
#   let counterItemsTotal = parseInt(counterFoundItemsTotal, 10),
#     counterItemsPagesMax = parseInt((counterItemsTotal / 10).toFixed(0), 10);
#
#   seg.searchElementsDOMConfigs[componentIndex].paginationInfo.itemsTotal = counterItemsTotal;
#   seg.searchElementsDOMConfigs[componentIndex].paginationInfo.pagesMax = counterItemsPagesMax;
#   seg.searchElementsDOMConfigs[componentIndex].paginationInfo.pagesCurrent = pageIndex;
#
#   seg.removePagination(componentIndex);
#
#   let paginationElementDOM = document.createElement('ul');
#   paginationElementDOM.id = 'm-search__pagination' + componentIndex;
#   paginationElementDOM.classList.add('m-search__pagination');
#   paginationElementDOM.dataset.pagecurrent = pageIndex.toString();
#
#   if (counterItemsPagesMax > 10) {
#     counterItemsPagesMax = 10;
#   }
#
#   for (let i = 0; i < counterItemsPagesMax; i++) {
#     let paginationPageItemElementDOM = document.createElement('li'),
#       pageIndexNumber = i + 1;
#
#     paginationPageItemElementDOM.classList.add('m-search__pagination__item');
#
#     if (pageIndex === pageIndexNumber) {
#       paginationPageItemElementDOM.classList.add('is-active');
#     }
#
#     paginationPageItemElementDOM.dataset.pageitem = pageIndexNumber.toString();
#     paginationPageItemElementDOM.innerHTML = pageIndexNumber.toString();
#     paginationPageItemElementDOM.addEventListener('click',
#       (event) => {
#         let clickedTarget = event.target.closest('.m-search__pagination__item');
#
#         console.log('clickedTarget', clickedTarget);
#
#         if (clickedTarget) {
#           let paginationItemPageIndex = parseInt(clickedTarget.dataset.pageitem, 10);
#           console.log('paginationItemPageIndex', paginationItemPageIndex);
#           this.initialLoadData(seg.activeSearchTerm, componentIndex, paginationItemPageIndex)
#
#           if (seg.searchElementsDOMConfigs[componentIndex].currentComponentViewMode === 0 && window) {
#             window.scrollTo(0, 0);
#           }
#         }
#       });
#
#     paginationElementDOM.appendChild(paginationPageItemElementDOM);
#   }
#
#   seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentMainElementDOM.appendChild(paginationElementDOM);
#   seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentPaginationElementDOM = paginationElementDOM;
# }
#
# searchGoogleController.prototype.removePagination = function (componentIndex) {
#   let currentPagination = document.getElementsByClassName('m-search__pagination')[0];
#   if (currentPagination) {
#     currentPagination.remove();
#     seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentPaginationElementDOM = null;
#   }
# }
# searchGoogleController.prototype.initSearchResultEmpty = function (componentIndex) {
#   let listingElementEmptyDOM = document.createElement('li');
#   listingElementEmptyDOM.classList.add(seg.searchResultEmptyClassnameDOM.replace('.', ''));
#
#   listingElementEmptyDOM.innerHTML = seg.componentLanguageActiveContent.resultsEmpty;
#
#   if (seg.searchElementsDOMConfigs[componentIndex]) {
#     this.removePagination(componentIndex);
#     if (seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentResultsContentElementDOM) {
#       seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentResultsContentElementDOM.innerHTML = '';
#       seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentResultsContentElementDOM.appendChild(listingElementEmptyDOM);
#     }
#     if (seg.searchElementsDOMConfigs[componentIndex].currentComponentViewMode === 1) {
#       if (seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentResultsElementDOM) {
#         seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentResultsElementDOM.classList.remove('is-visible');
#       }
#     }
#   }
# }
#
# searchGoogleController.prototype.resetResultsContainer = function (componentIndex) {
#   console.log('in resetResultsContainer');
#   if (seg.searchElementsDOMConfigs[componentIndex]) {
#     if (seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentResultsContentElementDOM) {
#       seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentResultsContentElementDOM.innerHTML = '';
#     }
#
#     if (seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentResultsElementDOM) {
#       seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentResultsElementDOM.classList.remove('is-visible');
#     }
#   }
# }
#
# searchGoogleController.prototype.getUrlParameters = function (url) {
#   // get query string from url (optional) or window
#   let queryString = url ? url.split('?')[1] : window.location.search.slice(1);
#
#   // we'll store the parameters here
#   let obj = {};
#
#   // if query string exists
#   if (queryString) {
#
#     // stuff after # is not part of query string, so get rid of it
#     queryString = queryString.split('#')[0];
#
#     // split our query string into its component parts
#     let arr = queryString.split('&');
#
#     for (let i = 0; i < arr.length; i++) {
#       // separate the keys and the values
#       let a = arr[i].split('=');
#
#       // set parameter name and value (use 'true' if empty)
#       let paramName = a[0];
#       let paramValue = typeof (a[1]) === 'undefined' ? true : a[1];
#
#       // (optional) keep case consistent
#       paramName = paramName.toLowerCase();
#       if (typeof paramValue === 'string') paramValue = paramValue.toLowerCase();
#
#       // if the paramName ends with square brackets, e.g. colors[] or colors[2]
#       if (paramName.match(/\[(\d+)?\]$/)) {
#
#         // create key if it doesn't exist
#         let key = paramName.replace(/\[(\d+)?\]/, '');
#         if (!obj[key]) obj[key] = [];
#
#         // if it's an indexed array e.g. colors[2]
#         if (paramName.match(/\[\d+\]$/)) {
#           // get the index value and add the entry at the appropriate position
#           let index = /\[(\d+)\]/.exec(paramName)[1];
#           obj[key][index] = paramValue;
#         } else {
#           // otherwise add the value to the end of the array
#           obj[key].push(paramValue);
#         }
#       } else {
#         // we're dealing with a string
#         if (!obj[paramName]) {
#           // if it doesn't exist, create property
#           obj[paramName] = paramValue;
#         } else if (obj[paramName] && typeof obj[paramName] === 'string') {
#           // if property does exist and it's a string, convert it to an array
#           obj[paramName] = [obj[paramName]];
#           obj[paramName].push(paramValue);
#         } else {
#           // otherwise add the property
#           obj[paramName].push(paramValue);
#         }
#       }
#     }
#   }
#
#   return obj;
# }
#
# searchGoogleController.prototype.removeComponent = function (componentIndex) {
#   if (seg.searchElementsDOMConfigs[componentIndex]) {
#     if (seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentMainElementDOM) {
#       seg.searchElementsDOMConfigs[componentIndex].elementsDOM.componentMainElementDOM.remove();
#     }
#   }
# }
#
# // initial load widget once in the code
# $(function () {
#   // check if mainElementDOM is available
#   // mainElementDOM should only be once in the DOM
#   // thats why we point on the 0 element in the upcoming elementList of document.getElementsByClassName
#   if (searchContainersClassnamesDOM !== undefined &&
#     searchContainersClassnamesDOM !== null &&
#     searchContainersClassnamesDOM.length > 0) {
#     for (let i = 0; i < searchContainersClassnamesDOM.length; i++) {
#       let componentConainerClassnameDOM = searchContainersClassnamesDOM[i],
#         mainElementDOM = document.getElementsByClassName(componentConainerClassnameDOM.replace('.', ''))[0];
#       if (mainElementDOM) {
#         let searchGoogleComponent = new searchGoogleController(),
#           searchElementConfigs = {
#             componentIndex: i,
#             mainElementClassnameDOM: componentConainerClassnameDOM,
#             currentComponentViewMode: 0,
#             searchTerm: null,
#             paginationInfo: null,
#             elementsDOM: null
#           };
#         console.log('initial loading of widget: ', searchGoogleComponent.componentName);
#         console.log('mainElementDOM exists: ', mainElementDOM);
#         searchGoogleComponent.searchElementsDOMConfigs.push(searchElementConfigs);
#         searchGoogleComponent.initComponentDOM(componentConainerClassnameDOM, mainElementDOM, i);
#       } else {
#         // if check failed, delete containers in DOM
#         // useful if a parent element is declared
#         console.warn('FAILED > initial loading of widget: ', componentName);
#       }
#     }
#   } else {
#     // no component container classnames are set
#     console.warn('FAILED > initial loading of widget: No component container classnames are set', componentName);
#   }
# });
#   </script>
#   <script data-usercentrics="Instagram Content" type="text/plain">
#    $('.feed-consent--instagram').each(function(){
#            var feedContainer = $(this).find('[data-embed-type="instagram"]');
#            var instagramEmbedCode = embedCodes[$(this).data("uuid")];
#            feedContainer.replaceWith( instagramEmbedCode );
#         });
#         var script = document.createElement('script');
#         script.async = true;
#         script.src = '//www.instagram.com/embed.js';
#         (document.getElementsByTagName('head')[0] || document.body).appendChild(script);
#   </script>
#   <script data-usercentrics="Twitter Embed" type="text/plain">
#    $('.feed-consent--twitter').each(function(){
#            var feedContainer = $(this).find('[data-embed-type="twitter"]');
#            var twitterEmbedCode = embedCodes[$(this).data("uuid")];
#            feedContainer.replaceWith( twitterEmbedCode );
#         });
#         var script = document.createElement('script');
#         script.async = true;
#         script.src = 'https://platform.twitter.com/widgets.js';
#         (document.getElementsByTagName('head')[0] || document.body).appendChild(script);
#   </script>
#   <script data-usercentrics="Facebook Social Plugins" type="text/plain">
#    $('.feed-consent--facebook').each(function(){
#            var feedContainer = $(this).find('[data-embed-type="facebook"]');
#            var facebookEmbedCode = embedCodes[$(this).data("uuid")];
#            feedContainer.replaceWith( facebookEmbedCode );
#         });
#   </script>
#   <script data-usercentrics="YouTube Video" type="text/plain">
#    $(".container--youtube").each(function() {
#       var videoId = $(this).attr('id');
#       var originalVideoContainer = '<div class="media-object media-object--youtube media-object--ratio16_9"><div class="video-container" data-video="https://www.youtube.com/embed/'+videoId+'" style="background:transparent url(https://cdn.muenchen-p.de/my-videos/'+videoId+'/sddefault.jpg) no-repeat center center;background-size:100% auto;"><div class="vcoverlay hvr-grow"></div></div></div>';
#
#       $(this).html(originalVideoContainer);
#       $(this).on('click', '.media-object--youtube', function() {
#         var videoContainer = $(this).find(".video-container");
#         var youtubeVideo = videoContainer.attr('data-video');
#         var videoFrame = '<iframe src="'+ youtubeVideo +'?rel=0&autoplay=1" frameborder="0" allowfullscreen></iframe>';
#         videoContainer.html(videoFrame );
#       });
#     });
#   </script>
#   <a class="back-to-top" href="#0">
#    Top
#   </a>
#   <div class="fullscreen-overlay fullscreen-overlay--slidedown fullscreen-overlay--below-header" id="modal-1622962004988">
#    <div class="fullscreen-overlay__content">
#     <div class="header__search-bar" data-componentindex="2" id="m-search_2">
#     </div>
#    </div>
#   </div>
#   <div class="fullscreen-overlay" id="fullscreen-overlay">
#   </div>
#   <div class="sidr left" id="sidr-main" style="transition: left 0.2s ease 0s;">
#    <div class="sidr-inner">
#     <div class="sidr-class-lmcontainer">
#      <div class="sidr-class-lmcontainer__item">
#       <a class="sidr-class-en" href="http://www.muenchen.de/int/en">
#       </a>
#      </div>
#      <div class="sidr-class-lmcontainer__item">
#       <a class="sidr-class-fr" href="http://www.muenchen.de/int/fr/">
#       </a>
#      </div>
#      <div class="sidr-class-lmcontainer__item">
#       <a class="sidr-class-it" href="http://www.muenchen.de/int/it/">
#       </a>
#      </div>
#      <div class="sidr-class-lmcontainer__item">
#       <a class="sidr-class-ru" href="http://www.muenchen.de/int/ru/">
#       </a>
#      </div>
#      <div class="sidr-class-lmcontainer__item">
#       <a class="sidr-class-ar" href="http://www.muenchen.de/int/ar/">
#       </a>
#      </div>
#      <div class="sidr-class-lmcontainer__item">
#       <a class="sidr-class-zh" href="http://www.muenchen.de/int/zh/">
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidr-inner">
#     <ul class="sidr-class-mainnav__list" role="navigation">
#      <!--<li id="mainMenuItem99999" class="mainnav__item">
#               <a href="http://www.muenchen.de" class="mainnav__home"><i class="fa fa-home" style="color:#fff;"></i></a>
#             </li>-->
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="0" id="sidr-id-mainMenuItem0">
#       <a class="" href="http://www.muenchen.de/rathaus/home.html">
#        <span>
#         Rathaus
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="1" id="sidr-id-mainMenuItem1">
#       <a class="" href="http://www.muenchen.de/branchenbuch">
#        <span>
#         Branchenbuch
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="2" id="sidr-id-mainMenuItem2">
#       <a class="" href="http://www.muenchen.de/veranstaltungen.html">
#        <span>
#         Veranstaltungen
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="3" id="sidr-id-mainMenuItem3">
#       <a class="" href="http://www.muenchen.de/kino.html">
#        <span>
#         Kino
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="4" id="sidr-id-mainMenuItem4">
#       <a class="" href="http://www.muenchen.de/freizeit.html">
#        <span>
#         Freizeit
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="5" id="sidr-id-mainMenuItem5">
#       <a class="" href="http://www.muenchen.de/sehenswuerdigkeiten.html">
#        <span>
#         Sehenswertes
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="6" id="sidr-id-mainMenuItem6">
#       <a class="" href="http://www.muenchen.de/essen-trinken.html">
#        <span>
#         Restaurants
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="7" id="sidr-id-mainMenuItem7">
#       <a class="" href="http://www.muenchen.de/shopping.html">
#        <span>
#         Shopping
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="8" id="sidr-id-mainMenuItem8">
#       <a class="" href="http://www.muenchen.de/uebernachten.html">
#        <span>
#         Hotels
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="9" id="sidr-id-mainMenuItem9">
#       <a class="" href="http://www.muenchen.de/verkehr.html">
#        <span>
#         Verkehr
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="10" id="sidr-id-mainMenuItem10">
#       <a class="" href="http://www.muenchen.de/rathaus/wirtschaft.html">
#        <span>
#         Wirtschaft
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="11" id="sidr-id-mainMenuItem11">
#       <a class="" href="http://www.muenchen.de/leben/job.html">
#        <span>
#         Jobs
#        </span>
#       </a>
#      </li>
#      <li class="sidr-class-mainnav__item" data-mdemainmenucount="12" id="sidr-id-mainMenuItem12">
#       <a class="" href="http://www.muenchen.de/leben.html">
#        <span>
#         Leben
#        </span>
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </body>
# </html>

# %%
driver.get(r'https://www.muenchen.de/service/branchenbuch/A/15.html')
content = driver.page_source
soup = BeautifulSoup(content)
leng = len(soup.find_all(itemprop="name"))
names = soup.find_all(itemprop="name")
addresses = soup.find_all(itemprop="streetAddress")
cities = soup.find_all(itemprop="addressLocality")
#soup.find_all('<span class="item__url item__url--address str" itemprop="streetAddress">')
#<span class="item__url item__url--address zip" itemprop="addressLocality">
outputFile = open('apotheken_muenchen.csv','w',newline='')
outputWriter = csv.writer(outputFile)
outputWriter.writerow(['Name', 'Straße', 'Ort'])

for k in range(0, len(names)):
    name = names[k].contents[0]
    name = name.strip('\n')
    name = name.strip()
    address = addresses[k].contents[0]
    address = address.strip('\n')
    address = address.strip()
    city = cities[k].contents[0]
    city = city.strip('\n')
    city = city.strip()
    outputWriter.writerow([name, address, city])

# %%
driver.get(r'https://www.muenchen.de/service/branchenbuch/A/15_2.html')
content = driver.page_source
soup = BeautifulSoup(content)
names = soup.find_all(itemprop="name")
addresses = soup.find_all(itemprop="streetAddress")
cities = soup.find_all(itemprop="addressLocality")
for k in range(0, len(names)):
    name = names[k].contents[0]
    name = name.strip('\n')
    name = name.strip()
    address = addresses[k].contents[0]
    address = address.strip('\n')
    address = address.strip()
    city = cities[k].contents[0]
    city = city.strip('\n')
    city = city.strip()
    outputWriter.writerow([name, address, city])

# %%
driver.get(r'https://www.muenchen.de/service/branchenbuch/A/15_3.html')
content = driver.page_source
soup = BeautifulSoup(content)
names = soup.find_all(itemprop="name")
addresses = soup.find_all(itemprop="streetAddress")
cities = soup.find_all(itemprop="addressLocality")
for k in range(0, len(names)):
    name = names[k].contents[0]
    name = name.strip('\n')
    name = name.strip()
    address = addresses[k].contents[0]
    address = address.strip('\n')
    address = address.strip()
    city = cities[k].contents[0]
    city = city.strip('\n')
    city = city.strip()
    outputWriter.writerow([name, address, city])
outputFile.close()

# %%
outputFile.close()
