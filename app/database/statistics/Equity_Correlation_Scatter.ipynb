# %%
#Import modules

import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sp
from scipy.stats import linregress
from scipy.stats import pearsonr
import seaborn as sns

print("Import successfull")
# Out:
# Import successfull

# %%
#Connection to database
conn = psycopg2.connect(database="goat", user="goat", password="earlmanigault", host="localhost", port="65432")
cur = conn.cursor()
print("Opened database successfully")
# Out:
# Opened database successfully

# %%
#Load data and pre processing
data = pd.read_sql_query("SELECT a.*, p.* from grid_access_20 a, grid_population p where a.grid_id = p.grid_id;", conn, index_col=None, coerce_float=True, params=None, parse_dates=None, chunksize=None)
print("Tables selected successfully")
# Out:
# Tables selected successfully

# %%
amenities_food = ['grocery_shops','supermarket','discount_supermarket','organic']
amenities_education = ['nursery','kindergarten','after_school','grundschule','hauptschule_mittelschule','realschule','gymnasium']
amenities_health = ['pharmacy','general_practitioner','paediatrician','gynaecologist','dentist']
amenities_transport = ['bus_stop','tram_stop','subway_entrance','rail_station']
origin = ['nomigr','migr','foreigner']
hh = ['hh_nochild','hh_child','hh_sp','hh_tp']

# %%
def plot(data,amenities,population):
    for category in amenities:
        df1 = data[data[category.lower()]>0]
        for userGroup in population:
            df2 = df1[df1[userGroup.lower()]>0]
            x = df2[category.lower()]
            y = df2[userGroup.lower()]
            plt.scatter(x, y)
            plt.plot(np.unique(x),
                    np.poly1d(np.polyfit(x,y,1))
                    (np.unique(x)))
        plt.legend(population)    
        plt.xlabel('accessibility index')
        plt.ylabel('population')
        plt.title(category.lower())
        plt.show()

# %%
def plot2(data,amenities,population):
    for category in amenities:
        df1 = data[data[category.lower()]>0]
        for userGroup in population:
            df2 = df1[df1[userGroup.lower()]>0]
            x = df2[category.lower()]
            y = df2[userGroup.lower()]
            plt.scatter(x, y)
            plt.plot(np.unique(x),
                    np.poly1d(np.polyfit(x,y,1))
                    (np.unique(x)))
        plt.legend(population)    
        plt.xlabel('accessibility index')
        plt.ylabel('households')
        plt.title(category.lower())
        plt.show()

# %%
plot(data,['nursery'],origin)
plot2(data,['nursery'],hh)

# %%
plot(data,['kindergarten'],origin)
plot2(data,['kindergarten'],hh)

# %%
plot(data,['after_school'],origin)
plot2(data,['after_school'],hh)

# %%
plot(data,['grundschule'],origin)
plot2(data,['grundschule'],hh)

# %%
plot(data,['hauptschule_mittelschule'],origin)
plot2(data,['hauptschule_mittelschule'],hh)

# %%
plot(data,['realschule'],origin)
plot2(data,['realschule'],hh)

# %%
plot(data,['gymnasium'],origin)
plot2(data,['gymnasium'],hh)

# %%
plot(data,['pharmacy'],origin)
plot2(data,['pharmacy'],hh)

# %%
plot(data,['dentist'],origin)
plot2(data,['dentist'],hh)

# %%
plot(data,['general_practitioner'],origin)
plot2(data,['general_practitioner'],hh)

# %%
plot(data,['paediatrician'],origin)
plot2(data,['paediatrician'],hh)

# %%
plot(data,['supermarket'],origin)
plot2(data,['supermarket'],hh)

# %%
plot(data,['discount_supermarket'],origin)
plot2(data,['discount_supermarket'],hh)

# %%
plot(data,['organic'],origin)
plot2(data,['organic'],hh)

# %%
plot(data,['bus_stop'],origin)
plot2(data,['bus_stop'],hh)

# %%
plot(data,['tram_stop'],origin)
plot2(data,['tram_stop'],hh)

# %%
plot(data,['subway_entrance'],origin)
plot2(data,['subway_entrance'],hh)

# %%
plot(data,['rail_station'],origin)
plot2(data,['rail_station'],hh)
